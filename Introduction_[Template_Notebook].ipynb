# %% [markdown]
# <a href="https://colab.research.google.com/github/archana-acharya-pro/Prompt-Generation/blob/master/Introduction_%5BTemplate_Notebook%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction:

# %% [markdown]
# ## New Section Name

# %% [markdown]
# ### New Section Name

# %% [markdown]
# ## Week: 1

# %% [markdown]
# ### New Section Name

# %% [markdown]
# ## Week: 2
#
# *   List item
# *   List item

# %% [markdown]
# ### New Section Name

# %% [markdown]
# # Toice Name:

# %% [markdown]
# ## New Section Name

# %% [markdown]
# ### New Section Name

# %% [markdown]
# ## Week: 1

# %% [markdown]
# ### New Section Name

# %% [markdown]
# ## Week: 2
#
# *   List item
# *   List item

# %% [markdown]
# ### New Section Name

# %% [markdown]
# # Toice Name:

# %% [markdown]
# ## New Section Name

# %% [markdown]
# ### New Section Name

# %% [markdown]
# ## New Section Name

# %% [markdown]
# ### New Section Name
