# %% [markdown]
# <a href="https://colab.research.google.com/github/archana-acharya-pro/Prompt-Generation/blob/master/notebooks/math_question_generator/MathQuestion_Prompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction: Prompt Generation
#
#
#
# 1.   Generat prompts for a specific typr of question
# 2.   Use the prompt to generate any number of questions and answers.
# 3.   Save the questions and answers in a defined format in a PDF for future print and use.

# %% [markdown]
# ## New Section Name
#
#
#
# *   File:

# %% [markdown]
# ### Generate the Prompt from given Question Sample

# %% [markdown]
# > Prompt
#
# >

# %% [markdown]
# ### Use the prompt, generated in previous setp, to get the file with questions and answers as a document (.docx) or as PDF file

# %%
"""



"""

# %% [markdown]
# ## New Section Name
#
#
#
# *   File:

# %% [markdown]
# ### Generate the Prompt from given Question Sample

# %% [markdown]
# > Prompt
#
# >

# %% [markdown]
# ### Use the prompt, generated in previous setp, to get the file with questions and answers as a document (.docx) or as PDF file

# %%
"""



"""

# %% [markdown]
# ## New Section Name
#
#
#
# *   File:

# %% [markdown]
# ### Generate the Prompt from given Question Sample

# %% [markdown]
# > Prompt
#
# >

# %% [markdown]
# ### Use the prompt, generated in previous setp, to get the file with questions and answers as a document (.docx) or as PDF file

# %%
"""



"""

# %% [markdown]
# ## Roman_To_Arabic
#
#
#
# *   File: Roman_To_Arabic_Practice_Pack_

# %% [markdown]
# ### Generate the Prompt from given Question Sample

# %% [markdown]
# > Prompt
#
# >
# for the given question:
#
# ```
# """
# Ronam to Arabic numeral
#   1. DXXXIX in arabic numeral is
#   2. CCCLXIV in arabic numeral is
#   3. MCMXCIX in arabic numeral is
#
# """
#
#
# ```
#
# Generate a prompt in the Given format:
#
# ```
# """
#
# Use the Saved Pattern: MathLeague.org Practice Pack Generation for following
#
# As a math teacher who writes MathLeague.org practice materials, create a complete “Multiply by 25” practice pack.
#
# Follow the PDF file structure provided.
#
# Follow this exact structure:
#
# Part A — 240 Practice Questions (Multiply by 25)
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Multiply each number by 25. Use the shortcut method (divide by 4, then multiply by 100) where helpful.
#
#     Write your answer in the space provided.
#
# • Use only 2-digit, 3-digit, 4-digit, 5-digit, or decimal numbers.
#
# • All questions must be of the form (number × 25) or (25 × number).
#
# • Include a balanced mix of whole numbers and decimals.
#
# • Format each question exactly like this:
#
#     1. 128 × 25 =
#
#     2. 25 × 1,284 =
#
#     3. 11,438 × 25 =
#
# • Do NOT repeat numbers.
#
# • Do NOT create sequential patterns.
#
# • Mix difficulty levels.
#
# • Provide space for answer between 2 columns.
#
# • Split questions in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Use markdown grid tables. Each table has 15 rows (30 questions total).
#
#   Example:
#
#   | 1. 128 × 25 = | 16. 25 × 34.5 = |
#
#   |----------------|------------------|
#
#   | 2. 25 × 5,234 = | 17. 729 × 25 = |
#
#   (continue for all 30 questions)
#
# • 8 tables total (Tables 1–8).
#
# Part B — Answer Key
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Check your answers below. Answers are in order. Use the shortcut to check your work.
#
# • Provide all 240 answers in order.
#
# • Format each answer exactly like this:
#
#     1. {Answer}
#
# • Split answers in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Same two-column, 15-row, 30-answer table layout as Part A.
#
#   Example:
#
#   | 1. 3200 | 16. 862.5 |
#
#   |---------|----------|
#
#   | 2. 130850 | 17. 18225 |
#
# • 8 tables total (Tables 1–8).
#
# Part C — Explanation Section
#
# • Explain the Multiply-by-25 shortcut.
#
# • Show why the method works.
#
# • Provide 5 fully worked examples.
#
# Part D — Math League Teaching Strategy
#
# • Provide speed tips, pattern recognition strategies, mental-math shortcuts, and common mistakes students make.
#
# Part E — Teacher Notes
#
# • Provide one paragraph of coaching advice for contest preparation.
#
# After generating all content, compile everything into a single downloadable PDF format (text ready to copy into a word processor).
#
# Output instructions:
#
# - Clean, minimal styling — simple grid, no heavy color blocks.
#
# - Questions run continuously with forced page breaks between sub-tables.
#
# - Questions and Answer key should have a page forced page break.
#
# - Answer key mirrors the same layout as the question tables.
#
# - Answer key runs continuously without forced page breaks between sub-tables.
#
# - Compile everything into a single downloadable PDF.
#
# """
#
#
#
# ```

# %% [markdown]
# ### Use the prompt, generated in previous setp, to get the file with questions and answers as a document (.docx) or as PDF file

# %%
"""

Use the Saved Pattern: MathLeague.org Practice Pack Generation for following

As a math teacher who writes MathLeague.org practice materials, create a
complete "Roman Numerals to Arabic Numerals" practice pack.

Follow the PDF file structure provided.

Follow this exact structure:

Part A — 240 Practice Questions (Roman Numerals to Arabic Numerals)

- Add a 1 or 2 line instruction like:
    Instructions: Convert each Roman numeral to its Arabic numeral
    equivalent. Apply additive and subtractive rules carefully.
    Write your answer in the space provided.

- Use Roman numerals covering the following value ranges,
  distributed evenly across all 240 questions (40 per range):

    - Range 1: 1–39
                e.g. I, IV, IX, XIV, XXIX, XXXIX
    - Range 2: 40–99
                e.g. XL, XLVIII, LXIV, XCIX
    - Range 3: 100–399
                e.g. CXLV, CCXLVII, CCCLXIV
    - Range 4: 400–899
                e.g. CDXLIV, DXXXIX, DCCCXCIX
    - Range 5: 900–1,999
                e.g. CMXCIX, MCMXCIX, MDCCCXLV
    - Range 6: 2,000–3,999
                e.g. MMXXIV, MMCMXCIX, MMMCCCIII

- All questions must be of the following form:
    "[Roman numeral] in Arabic numeral is      "

- Include a balanced mix of difficulty levels:
    - Easy:     Range 1 and 2 (values 1–99)
    - Medium:   Range 3 and 4 (values 100–899)
    - Hard:     Range 5 (values 900–1,999)
    - Advanced: Range 6 (values 2,000–3,999) and complex
                subtractive combinations across all ranges

- Format each question exactly like this:
    1. DXXXIX in Arabic numeral is
    2. CCCLXIV in Arabic numeral is
    3. MCMXCIX in Arabic numeral is

- Do NOT repeat Roman numeral values.
- Do NOT create sequential patterns.
- Mix all 6 ranges and difficulty levels throughout.
- Provide space for answer between 2 columns.
- Split questions in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Use markdown grid tables.
  Each table has 15 rows (30 questions total).
  Example:

  | 1.  DXXXIX in Arabic numeral is            | 16. MCMXCIX in Arabic numeral is           |
  |------------------------------------------|------------------------------------------|
  | 2.  CCCLXIV in Arabic numeral is           | 17. XLVIII in Arabic numeral is            |
  | 3.  MCMXCIX in Arabic numeral is           | 18. MMCCCXLV in Arabic numeral is          |
  | 4.  XIV in Arabic numeral is               | 19. CDXCII in Arabic numeral is            |
  | 5.  XCIX in Arabic numeral is              | 20. DCCCLXXXIX in Arabic numeral is        |
  (continue for all 30 questions)

- 8 tables total (Tables 1–8), 30 questions each = 240 total.
- Forced page break between each table.

Part B — Answer Key

- Add a 1 or 2 line instruction like:
    Instructions: Check your answers below. Answers are listed in
    order. Use the Roman numeral symbol table to verify your work.

- Provide all 240 answers in order.

- Format each answer exactly like this:
    1. {Arabic numeral}

- Split answers in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Same two-column, 15-row, 30-answer layout as Part A.
  Example:

  | 1.  539           | 16. 1,999          |
  |-------------------|--------------------|
  | 2.  364           | 17. 48             |
  | 3.  1,999         | 18. 2,345          |
  | 4.  14            | 19. 492            |
  | 5.  99            | 20. 889            |
  (continue for all 30 answers)

- 8 tables total (Tables 1–8), 30 answers each = 240 total.
- Answer key runs continuously without forced page breaks
  between sub-tables.
- Forced page break between Part A and Part B.

Part C — Explanation Section

- Explain the Roman numeral system:

    - The 7 core symbols and their values:
        I = 1,  V = 5,  X = 10,  L = 50,
        C = 100,  D = 500,  M = 1,000

    - Additive rule:
        When a symbol is followed by one of equal or lesser
        value, add it.
        e.g. VIII = 5 + 1 + 1 + 1 = 8
        e.g. LXVI = 50 + 10 + 5 + 1 = 66

    - Subtractive rule:
        When a smaller symbol precedes a larger one, subtract
        it. Only these 6 subtractive pairs are valid:
        IV = 4    IX = 9
        XL = 40   XC = 90
        CD = 400  CM = 900

    - Repetition rule:
        I, X, C, M may repeat up to 3 consecutive times.
        V, L, D may never repeat.

    - How to convert: scan left to right, apply subtractive
      pairs first, then add remaining symbols.

- Provide 5 fully worked examples:
    1. DXXXIX:
       D=500, XXX=30, IX=9  →  500+30+9 = 539
    2. CCCLXIV:
       CCC=300, LX=60, IV=4  →  300+60+4 = 364
    3. MCMXCIX:
       M=1000, CM=900, XC=90, IX=9  →  1000+900+90+9 = 1,999
    4. XLVIII:
       XL=40, V=5, III=3  →  40+5+3 = 48
    5. MMCCCXLV:
       MM=2000, CCC=300, XL=40, V=5  →  2000+300+40+5 = 2,345

Part D — Math League Teaching Strategy

- Provide speed tips, pattern recognition strategies, mental-math
  shortcuts, and common mistakes students make, including:
    - Adding instead of subtracting a smaller symbol that
      precedes a larger one
      (e.g. reading IX as 11 instead of 9)
    - Using invalid subtractive pairs
      (e.g. IC for 99 — only XCIX is correct)
    - Miscounting repeated symbols under time pressure
      (e.g. counting XXXX instead of stopping at XXX)
    - Confusing CM (900) with CD (400)
    - Confusing D (500) with C (100) in long numerals
    - Missing an embedded subtractive pair in a complex
      numeral (e.g. overlooking XC inside MCMXCIX)
    - Not scanning the full numeral before starting
      the conversion

Part E — Teacher Notes

- Provide one paragraph of coaching advice for contest preparation
  focused on Roman numeral to Arabic numeral conversion problems
  commonly seen in Math League competitions, including how to train
  students to instantly recognize all 6 subtractive pairs, develop
  a reliable left-to-right scanning habit, handle complex numerals
  like MCMXCIX and MMCMXCIX without errors, and build the speed
  needed to convert Range 5 and 6 numerals confidently under
  strict time pressure.

After generating all content, compile everything into a single
downloadable PDF format (text ready to copy into a word processor).

Output instructions:
- Clean, minimal styling — simple grid, no heavy color blocks.
- Questions run continuously with forced page breaks between sub-tables.
- Questions and Answer Key should have a forced page break between them.
- Answer key mirrors the same layout as the question tables.
- Answer key runs continuously without forced page breaks between
  sub-tables.
- Compile everything into a single downloadable PDF.

"""

# %% [markdown]
# ## Place_Value Or Digital Placement
#
#
#
# *   File: Place_Value_Practice_Pack_

# %% [markdown]
# ### Generate the Prompt from given Question Sample

# %% [markdown]
# > Prompt
#
# >
#
# for the given question:
#
# ```
# """
# Place value of a digit in a number or Digital placement
#   1. The units digit of 451.235 is
#   2. The thousands digit of 451.235 is
#   3. The tens digit of 451.235 is
#   4. The hundredths digit of 451 is
#   5. The units digit of 45 is
#   6. The thousands digit of 451235 is
#   7. The tens digit of 235 is
#   8. The thousands digit of 76873 is
#
# """
#
#
#
#
#
# ```
#
# Generate a prompt in the Given format:
#
# ```
# """
#
# Use the Saved Pattern: MathLeague.org Practice Pack Generation for following
#
# As a math teacher who writes MathLeague.org practice materials, create a complete “Multiply by 25” practice pack.
#
# Follow the PDF file structure provided.
#
# Follow this exact structure:
#
# Part A — 240 Practice Questions (Multiply by 25)
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Multiply each number by 25. Use the shortcut method (divide by 4, then multiply by 100) where helpful.
#
#     Write your answer in the space provided.
#
# • Use only 2-digit, 3-digit, 4-digit, 5-digit, or decimal numbers.
#
# • All questions must be of the form (number × 25) or (25 × number).
#
# • Include a balanced mix of whole numbers and decimals.
#
# • Format each question exactly like this:
#
#     1. 128 × 25 =
#
#     2. 25 × 1,284 =
#
#     3. 11,438 × 25 =
#
# • Do NOT repeat numbers.
#
# • Do NOT create sequential patterns.
#
# • Mix difficulty levels.
#
# • Provide space for answer between 2 columns.
#
# • Split questions in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Use markdown grid tables. Each table has 15 rows (30 questions total).
#
#   Example:
#
#   | 1. 128 × 25 = | 16. 25 × 34.5 = |
#
#   |----------------|------------------|
#
#   | 2. 25 × 5,234 = | 17. 729 × 25 = |
#
#   (continue for all 30 questions)
#
# • 8 tables total (Tables 1–8).
#
# Part B — Answer Key
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Check your answers below. Answers are in order. Use the shortcut to check your work.
#
# • Provide all 240 answers in order.
#
# • Format each answer exactly like this:
#
#     1. {Answer}
#
# • Split answers in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Same two-column, 15-row, 30-answer table layout as Part A.
#
#   Example:
#
#   | 1. 3200 | 16. 862.5 |
#
#   |---------|----------|
#
#   | 2. 130850 | 17. 18225 |
#
# • 8 tables total (Tables 1–8).
#
# Part C — Explanation Section
#
# • Explain the Multiply-by-25 shortcut.
#
# • Show why the method works.
#
# • Provide 5 fully worked examples.
#
# Part D — Math League Teaching Strategy
#
# • Provide speed tips, pattern recognition strategies, mental-math shortcuts, and common mistakes students make.
#
# Part E — Teacher Notes
#
# • Provide one paragraph of coaching advice for contest preparation.
#
# After generating all content, compile everything into a single downloadable PDF format (text ready to copy into a word processor).
#
# Output instructions:
#
# - Clean, minimal styling — simple grid, no heavy color blocks.
#
# - Questions run continuously with forced page breaks between sub-tables.
#
# - Questions and Answer key should have a page forced page break.
#
# - Answer key mirrors the same layout as the question tables.
#
# - Answer key runs continuously without forced page breaks between sub-tables.
#
# - Compile everything into a single downloadable PDF.
#
# """
#
#
#
#
#
# ```

# %% [markdown]
# ### Use the prompt, generated in previous setp, to get the file with questions and answers as a document (.docx) or as PDF file

# %%
"""

Use the Saved Pattern: MathLeague.org Practice Pack Generation for following

As a math teacher who writes MathLeague.org practice materials, create a
complete "Place Value & Digit Identification" practice pack.

Follow the PDF file structure provided.

Follow this exact structure:

Part A — 240 Practice Questions (Place Value & Digit Identification)

- Add a 1 or 2 line instruction like:
    Instructions: Identify the digit at the named place value position
    in each number. Write only the single digit (0–9) as your answer
    in the space provided. Write "N/A" if the position does not exist
    in the given number.

- Use the following number types across all 240 questions:
    - 2-digit whole numbers       (e.g. 45)
    - 3-digit whole numbers       (e.g. 235)
    - 4-digit whole numbers       (e.g. 4,512)
    - 5-digit whole numbers       (e.g. 76,873)
    - 6-digit whole numbers       (e.g. 451,235)
    - Decimal numbers             (e.g. 451.235, 3.07)

- All questions must be of the following form:
    "The [place value name] digit of [number] is      "

- Use the following place value positions across all 240 questions,
  distributed evenly:

    Whole number positions:
        - units (ones)
        - tens
        - hundreds
        - thousands
        - ten-thousands
        - hundred-thousands

    Decimal positions (for decimal numbers only):
        - tenths
        - hundredths
        - thousandths

- CRITICAL VALIDITY RULES:
    Rule 1 — Position must exist:
        Only ask for a place value that exists in the number.
        e.g. "The thousands digit of 235 is      " is INVALID
             because 235 has no thousands digit.
        e.g. "The hundreds digit of 235 is      " is VALID → 2
    Rule 2 — Decimal positions only for decimal numbers:
        Only ask tenths/hundredths/thousandths for numbers
        that have a decimal point.
        e.g. "The hundredths digit of 451 is      " is INVALID
             because 451 is a whole number with no decimal.
    Rule 3 — Zero is a valid digit answer:
        If the digit at a position is 0, the answer is 0.

- Include a balanced mix of difficulty levels:
    - Easy:     units, tens, hundreds using 2- to 3-digit
                whole numbers
                e.g. The units digit of 45 is        → 5
                e.g. The tens digit of 235 is        → 3
    - Medium:   thousands, ten-thousands using 4- to 5-digit
                whole numbers
                e.g. The thousands digit of 76,873 is        → 6
    - Hard:     hundred-thousands using 6-digit whole numbers
                e.g. The thousands digit of 451,235 is       → 1
    - Advanced: tenths, hundredths, thousandths using decimal
                numbers
                e.g. The hundredths digit of 451.235 is       → 3

- Format each question exactly like this:
    1. The units digit of 451.235 is
    2. The thousands digit of 451,235 is
    3. The tens digit of 451.235 is
    4. The units digit of 45 is
    5. The hundred-thousands digit of 451,235 is
    6. The tens digit of 235 is
    7. The thousands digit of 76,873 is
    8. The hundredths digit of 451.235 is

- Do NOT repeat the same number-and-place-value combination.
- Do NOT create sequential patterns in the numbers used.
- Do NOT generate any question that violates the 3 validity
  rules above.
- Mix place value positions, number types, and difficulty
  levels throughout.
- Provide space for answer between 2 columns.
- Split questions in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Use markdown grid tables.
  Each table has 15 rows (30 questions total).
  Example:

  | 1.  The units digit of 451.235 is                | 16. The thousands digit of 76,873 is             |
  |------------------------------------------------|------------------------------------------------|
  | 2.  The thousands digit of 451,235 is            | 17. The tens digit of 892 is                     |
  | 3.  The tens digit of 451.235 is                 | 18. The hundredths digit of 73.406 is            |
  | 4.  The units digit of 45 is                     | 19. The hundred-thousands digit of 614,782 is __|
  | 5.  The hundred-thousands digit of             | 20. The tenths digit of 29.357 is                |
  |     451,235 is                                   |                                                |
  (continue for all 30 questions)

- 8 tables total (Tables 1–8), 30 questions each = 240 total.
- Forced page break between each table.

Part B — Answer Key

- Add a 1 or 2 line instruction like:
    Instructions: Check your answers below. Each answer is a single
    digit (0–9). Use the place value chart to verify your work.

- Provide all 240 answers in order.

- Format each answer exactly like this:
    1. {single digit 0–9}

- Split answers in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Same two-column, 15-row, 30-answer layout as Part A.
  Example:

  | 1.  1             | 16. 6              |
  |-------------------|--------------------|
  | 2.  1             | 17. 9              |
  | 3.  5             | 18. 0              |
  | 4.  5             | 19. 6              |
  | 5.  4             | 20. 3              |
  (continue for all 30 answers)

- 8 tables total (Tables 1–8), 30 answers each = 240 total.
- Answer key runs continuously without forced page breaks
  between sub-tables.
- Forced page break between Part A and Part B.

Part C — Explanation Section

- Explain what place value means for both whole numbers
  and decimals.
- Show the complete place value chart from hundred-thousands
  to thousandths, with a sample number mapped to each position:

    Position:   Hundred-  | Ten-     |          |          |      |       |   |        |            |
                Thousands | Thousands| Thousands| Hundreds | Tens | Units | . | Tenths |Hundredths  | Thousandths

    Example — 451,235:
        4 → hundred-thousands
        5 → ten-thousands
        1 → thousands
        2 → hundreds
        3 → tens
        5 → units

    Example — 451.235:
        4 → hundreds
        5 → tens
        1 → units
        . → decimal point
        2 → tenths
        3 → hundredths
        5 → thousandths

    Example — 76,873:
        7 → ten-thousands
        6 → thousands
        8 → hundreds
        7 → tens
        3 → units

- Explain the three validity rules:
    Rule 1: Only ask for positions that exist in the number.
    Rule 2: Decimal positions only apply to decimal numbers.
    Rule 3: Zero is always a valid digit answer.

- Explain the symmetry around the decimal point:
    tens ↔ tenths, hundreds ↔ hundredths,
    thousands ↔ thousandths
    (There is no "oneths" — the decimal side starts at tenths)

- Provide 5 fully worked examples:
    1. The units digit of 451.235        (Easy — answer: 1)
    2. The thousands digit of 451,235    (Medium — answer: 1)
    3. The tens digit of 235             (Easy — answer: 3)
    4. The thousands digit of 76,873     (Medium — answer: 6)
    5. The hundredths digit of 451.235   (Advanced — answer: 3)

Part D — Math League Teaching Strategy

- Provide speed tips, pattern recognition strategies, mental-math
  shortcuts, and common mistakes students make, including:
    - Confusing "tens" with "tenths" and "hundreds" with
      "hundredths" (the most common mirror-image error)
    - Asking for a position that does not exist in the number
      (e.g. thousands digit of a 3-digit number)
    - Answering with the place value name instead of the digit
      (e.g. writing "hundreds" instead of "4")
    - Forgetting that 0 is a valid digit answer
    - Off-by-one position errors when counting digits in a
      long number
    - Confusing digit (numeral 0–9) with place value
      (digit × positional value)
    - Misreading commas as decimal points in large numbers
      (e.g. confusing 451,235 with 451.235)

Part E — Teacher Notes

- Provide one paragraph of coaching advice for contest preparation
  focused on place value and digit identification problems commonly
  seen in Math League competitions, including how to train students
  to instantly map any number onto a place value chart, apply the
  three validity rules automatically, avoid the classic tens/tenths
  mirror confusion, recognize zero as a legitimate answer, and
  respond accurately to all difficulty levels under time pressure.

After generating all content, compile everything into a single
downloadable PDF format (text ready to copy into a word processor).

Output instructions:
- Clean, minimal styling — simple grid, no heavy color blocks.
- Questions run continuously with forced page breaks between sub-tables.
- Questions and Answer Key should have a forced page break between them.
- Answer key mirrors the same layout as the question tables.
- Answer key runs continuously without forced page breaks between
  sub-tables.
- Compile everything into a single downloadable PDF.

"""

# %% [markdown]
# ## LCM
#
#
#
# *   File:

# %% [markdown]
# ### Generate the Prompt from given Question Sample

# %% [markdown]
# > Prompt
#
# >
# ```markdown
# for the given question:
#
# """
#
# The LCM of 18 and 24 is
#
# """
#
# Generate a prompt in the Given format:
#
# """
# Use the Saved Pattern: MathLeague.org Practice Pack Generation for following
#
# As a math teacher who writes MathLeague.org practice materials, create a complete “Multiply by 25” practice pack.
#
# Follow the PDF file structure provided.
#
# Follow this exact structure:
#
# Part A — 240 Practice Questions (Multiply by 25)
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Multiply each number by 25. Use the shortcut method (divide by 4, then multiply by 100) where helpful.
#
#     Write your answer in the space provided.
#
# • Use only 2-digit, 3-digit, 4-digit, 5-digit, or decimal numbers.
#
# • All questions must be of the form (number × 25) or (25 × number).
#
# • Include a balanced mix of whole numbers and decimals.
#
# • Format each question exactly like this:
#
#     1. 128 × 25 =
#
#     2. 25 × 1,284 =
#
#     3. 11,438 × 25 =
#
# • Do NOT repeat numbers.
#
# • Do NOT create sequential patterns.
#
# • Mix difficulty levels.
#
# • Provide space for answer between 2 columns.
#
# • Split questions in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Use markdown grid tables. Each table has 15 rows (30 questions total).
#
#   Example:
#
#   | 1. 128 × 25 = | 16. 25 × 34.5 = |
#
#   |----------------|------------------|
#
#   | 2. 25 × 5,234 = | 17. 729 × 25 = |
#
#   (continue for all 30 questions)
#
# • 8 tables total (Tables 1–8).
#
# Part B — Answer Key
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Check your answers below. Answers are in order. Use the shortcut to check your work.
#
# • Provide all 240 answers in order.
#
# • Format each answer exactly like this:
#
#     1. {Answer}
#
# • Split answers in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Same two-column, 15-row, 30-answer table layout as Part A.
#
#   Example:
#
#   | 1. 3200 | 16. 862.5 |
#
#   |---------|----------|
#
#   | 2. 130850 | 17. 18225 |
#
# • 8 tables total (Tables 1–8).
#
# Part C — Explanation Section
#
# • Explain the Multiply-by-25 shortcut.
#
# • Show why the method works.
#
# • Provide 5 fully worked examples.
#
# Part D — Math League Teaching Strategy
#
# • Provide speed tips, pattern recognition strategies, mental-math shortcuts, and common mistakes students make.
#
# Part E — Teacher Notes
#
# • Provide one paragraph of coaching advice for contest preparation.
#
# After generating all content, compile everything into a single downloadable PDF format (text ready to copy into a word processor).
#
# Output instructions:
#
# - Clean, minimal styling — simple grid, no heavy color blocks.
#
# - Questions run continuously with forced page breaks between sub-tables.
#
# - Questions and Answer key should have a page forced page break.
#
# - Answer key mirrors the same layout as the question tables.
#
# - Answer key runs continuously without forced page breaks between sub-tables.
#
# - Compile everything into a single downloadable PDF.
#
# """
#
#
#
#
# ```

# %% [markdown]
# ### Use the prompt, generated in previous setp, to get the file with questions and answers as a document (.docx) or as PDF file

# %%
"""

Use the Saved Pattern: MathLeague.org Practice Pack Generation for following

As a math teacher who writes MathLeague.org practice materials, create a
complete "LCM (Least Common Multiple)" practice pack.

Follow the PDF file structure provided.

Follow this exact structure:

Part A — 240 Practice Questions (LCM)

- Add a 1 or 2 line instruction like:
    Instructions: Find the Least Common Multiple (LCM) of each set
    of numbers. Use the Prime Factorization or Listing Multiples method
    where helpful. Write your answer in the space provided.

- Use only pairs or triples of whole numbers.

- All questions must be of the form:
    "The LCM of [a] and [b] is     "
    "The LCM of [a], [b], and [c] is     "

- Include a balanced mix of difficulty levels:
    - Easy:     two numbers between 2–20
    - Medium:   two numbers between 10–50
    - Hard:     two numbers between 50–200
    - Advanced: three numbers between 6–60

- Format each question exactly like this:
    1. The LCM of 18 and 24 is
    2. The LCM of 36 and 48 is
    3. The LCM of 12, 18, and 30 is

- Do NOT repeat number pairs or triples.
- Do NOT create sequential patterns.
- Mix difficulty levels throughout.
- Provide space for answer between 2 columns.
- Split questions in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Use markdown grid tables.
  Each table has 15 rows (30 questions total).
  Example:

  | 1.  The LCM of 18 and 24 is           | 16. The LCM of 12, 18, and 30 is      |
  |--------------------------------------|--------------------------------------|
  | 2.  The LCM of 36 and 48 is           | 17. The LCM of 45 and 60 is           |
  | 3.  The LCM of 15 and 25 is           | 18. The LCM of 8, 12, and 20 is       |
  | 4.  The LCM of 72 and 96 is           | 19. The LCM of 14 and 21 is           |
  | 5.  The LCM of 6, 9, and 15 is        | 20. The LCM of 100 and 150 is         |
  (continue for all 30 questions)

- 8 tables total (Tables 1–8), 30 questions each = 240 total.
- Forced page break between each table.

Part B — Answer Key

- Add a 1 or 2 line instruction like:
    Instructions: Check your answers below. Answers are listed in
    order. Use the Prime Factorization method to verify your work.

- Provide all 240 answers in order.

- Format each answer exactly like this:
    1. {Answer}

- Split answers in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Same two-column, 15-row, 30-answer layout as Part A.
  Example:

  | 1.  72           | 16. 180           |
  |------------------|-------------------|
  | 2.  144          | 17. 180           |
  | 3.  75           | 18. 120           |
  | 4.  288          | 19. 42            |
  | 5.  18           | 20. 300           |
  (continue for all 30 answers)

- 8 tables total (Tables 1–8), 30 answers each = 240 total.
- Answer key runs continuously without forced page breaks
  between sub-tables.
- Forced page break between Part A and Part B.

Part C — Explanation Section

- Explain what LCM (Least Common Multiple) means.
- Show two methods:

    Method 1 — Listing Multiples:
        List multiples of each number until a common multiple
        appears, then identify the smallest one.
        e.g. LCM of 18 and 24:
             Multiples of 18: 18, 36, 54, 72, 90 ...
             Multiples of 24: 24, 48, 72, 96 ...
             First common multiple: 72  →  LCM = 72

    Method 2 — Prime Factorization:
        Write each number as a product of prime factors.
        Multiply together each prime factor at its highest
        power appearing in any of the numbers.
        e.g. LCM of 18 and 24:
             18 = 2¹ × 3²
             24 = 2³ × 3¹
             LCM = 2³ × 3² = 8 × 9 = 72

- Explain why each method works.
- Show how to extend both methods to three numbers.
- Provide 5 fully worked examples:
    1. The LCM of 18 and 24        (Easy — listing multiples)
    2. The LCM of 36 and 48        (Medium — prime factorization)
    3. The LCM of 72 and 96        (Hard — prime factorization)
    4. The LCM of 12, 18, and 30   (Advanced — three numbers)
    5. The LCM of 100 and 150      (Medium — listing multiples)

Part D — Math League Teaching Strategy

- Provide speed tips, pattern recognition strategies, mental-math
  shortcuts, and common mistakes students make, including:
    - Confusing LCM with GCF and solving the wrong problem
    - Stopping too early when listing multiples before finding
      the first common one
    - Using the lowest power instead of the highest power of
      shared primes when applying prime factorization
    - Forgetting to include non-shared prime factors when
      building the LCM from prime factorizations
    - Extending to three numbers: forgetting to take the
      highest power across all three factorizations
    - Misidentifying prime vs. composite numbers when building
      the prime factorization tree
    - Confusing the LCM shortcut formula
      LCM(a,b) = (a × b) ÷ GCF(a,b) and applying it
      incorrectly

Part E — Teacher Notes

- Provide one paragraph of coaching advice for contest preparation
  focused on LCM problem types commonly seen in Math League
  competitions, including how to train students to quickly choose
  between the Listing Multiples and Prime Factorization methods
  based on the size of the numbers given, how to use the
  LCM = (a × b) ÷ GCF shortcut for two-number problems, and
  how to handle three-number LCM problems accurately and
  confidently under time pressure.

After generating all content, compile everything into a single
downloadable PDF format (text ready to copy into a word processor).

Output instructions:
- Clean, minimal styling — simple grid, no heavy color blocks.
- Questions run continuously with forced page breaks between sub-tables.
- Questions and Answer Key should have a forced page break between them.
- Answer key mirrors the same layout as the question tables.
- Answer key runs continuously without forced page breaks between
  sub-tables.
- Compile everything into a single downloadable PDF.

"""

# %% [markdown]
# ## GCD
#
#
#
# *   File:

# %% [markdown]
# ### Generate the Prompt from given Question Sample

# %% [markdown]
# > Prompt
#
# >
# ```markdown
# for the given question:
#
# """
#
# The GCD of 18 and 24 is
#
# """
#
# Generate a prompt in the Given format:
#
# """
# Use the Saved Pattern: MathLeague.org Practice Pack Generation for following
#
# As a math teacher who writes MathLeague.org practice materials, create a complete “Multiply by 25” practice pack.
#
# Follow the PDF file structure provided.
#
# Follow this exact structure:
#
# Part A — 240 Practice Questions (Multiply by 25)
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Multiply each number by 25. Use the shortcut method (divide by 4, then multiply by 100) where helpful.
#
#     Write your answer in the space provided.
#
# • Use only 2-digit, 3-digit, 4-digit, 5-digit, or decimal numbers.
#
# • All questions must be of the form (number × 25) or (25 × number).
#
# • Include a balanced mix of whole numbers and decimals.
#
# • Format each question exactly like this:
#
#     1. 128 × 25 =
#
#     2. 25 × 1,284 =
#
#     3. 11,438 × 25 =
#
# • Do NOT repeat numbers.
#
# • Do NOT create sequential patterns.
#
# • Mix difficulty levels.
#
# • Provide space for answer between 2 columns.
#
# • Split questions in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Use markdown grid tables. Each table has 15 rows (30 questions total).
#
#   Example:
#
#   | 1. 128 × 25 = | 16. 25 × 34.5 = |
#
#   |----------------|------------------|
#
#   | 2. 25 × 5,234 = | 17. 729 × 25 = |
#
#   (continue for all 30 questions)
#
# • 8 tables total (Tables 1–8).
#
# Part B — Answer Key
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Check your answers below. Answers are in order. Use the shortcut to check your work.
#
# • Provide all 240 answers in order.
#
# • Format each answer exactly like this:
#
#     1. {Answer}
#
# • Split answers in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Same two-column, 15-row, 30-answer table layout as Part A.
#
#   Example:
#
#   | 1. 3200 | 16. 862.5 |
#
#   |---------|----------|
#
#   | 2. 130850 | 17. 18225 |
#
# • 8 tables total (Tables 1–8).
#
# Part C — Explanation Section
#
# • Explain the Multiply-by-25 shortcut.
#
# • Show why the method works.
#
# • Provide 5 fully worked examples.
#
# Part D — Math League Teaching Strategy
#
# • Provide speed tips, pattern recognition strategies, mental-math shortcuts, and common mistakes students make.
#
# Part E — Teacher Notes
#
# • Provide one paragraph of coaching advice for contest preparation.
#
# After generating all content, compile everything into a single downloadable PDF format (text ready to copy into a word processor).
#
# Output instructions:
#
# - Clean, minimal styling — simple grid, no heavy color blocks.
#
# - Questions run continuously with forced page breaks between sub-tables.
#
# - Questions and Answer key should have a page forced page break.
#
# - Answer key mirrors the same layout as the question tables.
#
# - Answer key runs continuously without forced page breaks between sub-tables.
#
# - Compile everything into a single downloadable PDF.
#
# """
#
#
# ```

# %% [markdown]
# ### Use the prompt, generated in previous setp, to get the file with questions and answers as a document (.docx) or as PDF file

# %%
"""

Use the Saved Pattern: MathLeague.org Practice Pack Generation for following

As a math teacher who writes MathLeague.org practice materials, create a
complete "GCD (Greatest Common Divisor)" practice pack.

Follow the PDF file structure provided.

Follow this exact structure:

Part A — 240 Practice Questions (GCD)

- Add a 1 or 2 line instruction like:
    Instructions: Find the Greatest Common Divisor (GCD) of each set
    of numbers. Use the Prime Factorization or Listing Factors method
    where helpful. Write your answer in the space provided.

- Use only pairs or triples of whole numbers.

- All questions must be of the form:
    "The GCD of [a] and [b] is     "
    "The GCD of [a], [b], and [c] is     "

- Include a balanced mix of difficulty levels:
    - Easy:     two numbers between 2–20
    - Medium:   two numbers between 10–50
    - Hard:     two numbers between 50–200
    - Advanced: three numbers between 6–60

- Format each question exactly like this:
    1. The GCD of 18 and 24 is
    2. The GCD of 36 and 48 is
    3. The GCD of 12, 18, and 30 is

- Do NOT repeat number pairs or triples.
- Do NOT create sequential patterns.
- Mix difficulty levels throughout.
- Provide space for answer between 2 columns.
- Split questions in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Use markdown grid tables.
  Each table has 15 rows (30 questions total).
  Example:

  | 1.  The GCD of 18 and 24 is           | 16. The GCD of 12, 18, and 30 is      |
  |--------------------------------------|--------------------------------------|
  | 2.  The GCD of 36 and 48 is           | 17. The GCD of 45 and 60 is           |
  | 3.  The GCD of 15 and 25 is           | 18. The GCD of 8, 12, and 20 is       |
  | 4.  The GCD of 72 and 96 is           | 19. The GCD of 14 and 21 is           |
  | 5.  The GCD of 6, 9, and 15 is        | 20. The GCD of 100 and 150 is         |
  (continue for all 30 questions)

- 8 tables total (Tables 1–8), 30 questions each = 240 total.
- Forced page break between each table.

Part B — Answer Key

- Add a 1 or 2 line instruction like:
    Instructions: Check your answers below. Answers are listed in
    order. Use the Prime Factorization method to verify your work.

- Provide all 240 answers in order.

- Format each answer exactly like this:
    1. {Answer}

- Split answers in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Same two-column, 15-row, 30-answer layout as Part A.
  Example:

  | 1.  6            | 16. 6             |
  |------------------|-------------------|
  | 2.  12           | 17. 15            |
  | 3.  5            | 18. 4             |
  | 4.  24           | 19. 7             |
  | 5.  3            | 20. 50            |
  (continue for all 30 answers)

- 8 tables total (Tables 1–8), 30 answers each = 240 total.
- Answer key runs continuously without forced page breaks
  between sub-tables.
- Forced page break between Part A and Part B.

Part C — Explanation Section

- Explain what GCD (Greatest Common Divisor) means.
- Show two methods:

    Method 1 — Listing Factors:
        List all factors of each number, then identify the
        largest factor common to both (or all three) lists.
        e.g. GCD of 18 and 24:
             Factors of 18: 1, 2, 3, 6, 9, 18
             Factors of 24: 1, 2, 3, 4, 6, 8, 12, 24
             Common factors: 1, 2, 3, 6  →  GCD = 6

    Method 2 — Prime Factorization:
        Write each number as a product of prime factors.
        Multiply together only the prime factors shared by
        all numbers, using the lowest power of each.
        e.g. GCD of 18 and 24:
             18 = 2¹ × 3²
             24 = 2³ × 3¹
             Shared: 2¹ × 3¹ = 6  →  GCD = 6

- Explain why each method works.
- Show how to extend both methods to three numbers.
- Provide 5 fully worked examples:
    1. The GCD of 18 and 24        (Easy — listing factors)
    2. The GCD of 36 and 48        (Medium — prime factorization)
    3. The GCD of 72 and 96        (Hard — prime factorization)
    4. The GCD of 12, 18, and 30   (Advanced — three numbers)
    5. The GCD of 100 and 150      (Medium — listing factors)

Part D — Math League Teaching Strategy

- Provide speed tips, pattern recognition strategies, mental-math
  shortcuts, and common mistakes students make, including:
    - Confusing GCD with LCM and solving the wrong problem
    - Stopping too early when listing factors and missing the
      greatest common one
    - Forgetting that GCD = 1 when numbers share no common
      factor greater than 1 (coprime numbers)
    - Errors in prime factorization leading to wrong shared
      prime factors
    - Using the highest power instead of the lowest power of
      shared primes when applying prime factorization
    - Extending to three numbers: forgetting to check all three
      factorizations simultaneously
    - Misidentifying prime vs. composite numbers when building
      the prime factorization tree

Part E — Teacher Notes

- Provide one paragraph of coaching advice for contest preparation
  focused on GCD problem types commonly seen in Math League
  competitions, including how to train students to quickly choose
  between the Listing Factors and Prime Factorization methods
  based on the size of the numbers given, and how to handle
  three-number GCD problems accurately and confidently under
  time pressure.

After generating all content, compile everything into a single
downloadable PDF format (text ready to copy into a word processor).

Output instructions:
- Clean, minimal styling — simple grid, no heavy color blocks.
- Questions run continuously with forced page breaks between sub-tables.
- Questions and Answer Key should have a forced page break between them.
- Answer key mirrors the same layout as the question tables.
- Answer key runs continuously without forced page breaks between
  sub-tables.
- Compile everything into a single downloadable PDF.

"""

# %% [markdown]
# ## Estimate
#
#
#
# *   File: Estimate_Practice_Pack_

# %% [markdown]
# ### Generate the Prompt from given Question Sample

# %% [markdown]
# > Prompt
#
# >
# for the given question:
#
# """
# (estimate) 1385 + 1289 - 679
# (estimate) 209 * 499
# (estimate) 39 * 49 * 43
# (estimate) 9 * 428571
# (estimate) 849512 / 169
# (estimate) sqrt 824892
# (estimate) 667 x 81
# (estimate) 3.1 power of 4
# (estimate) 333 power of 2
# (estimate) 333 power of 4
# (estimate) the area of the circle with radius 4 sqrt 2 is
# (estimate) cube root of 824892
# (estimate) square (43) x square (47) / 10 power 4
# (estimate) (43  power 2) x (47 power 2) / 10 power 4
#
#
#
# """
#
# Generate a prompt in the Given format:
#
# """
#
# Use the Saved Pattern: MathLeague.org Practice Pack Generation for following
#
# As a math teacher who writes MathLeague.org practice materials, create a complete “Multiply by 25” practice pack.
#
# Follow the PDF file structure provided.
#
# Follow this exact structure:
#
# Part A — 240 Practice Questions (Multiply by 25)
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Multiply each number by 25. Use the shortcut method (divide by 4, then multiply by 100) where helpful.
#
#     Write your answer in the space provided.
#
# • Use only 2-digit, 3-digit, 4-digit, 5-digit, or decimal numbers.
#
# • All questions must be of the form (number × 25) or (25 × number).
#
# • Include a balanced mix of whole numbers and decimals.
#
# • Format each question exactly like this:
#
#     1. 128 × 25 =
#
#     2. 25 × 1,284 =
#
#     3. 11,438 × 25 =
#
# • Do NOT repeat numbers.
#
# • Do NOT create sequential patterns.
#
# • Mix difficulty levels.
#
# • Provide space for answer between 2 columns.
#
# • Split questions in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Use markdown grid tables. Each table has 15 rows (30 questions total).
#
#   Example:
#
#   | 1. 128 × 25 = | 16. 25 × 34.5 = |
#
#   |----------------|------------------|
#
#   | 2. 25 × 5,234 = | 17. 729 × 25 = |
#
#   (continue for all 30 questions)
#
# • 8 tables total (Tables 1–8).
#
# Part B — Answer Key
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Check your answers below. Answers are in order. Use the shortcut to check your work.
#
# • Provide all 240 answers in order.
#
# • Format each answer exactly like this:
#
#     1. {Answer}
#
# • Split answers in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Same two-column, 15-row, 30-answer table layout as Part A.
#
#   Example:
#
#   | 1. 3200 | 16. 862.5 |
#
#   |---------|----------|
#
#   | 2. 130850 | 17. 18225 |
#
# • 8 tables total (Tables 1–8).
#
# Part C — Explanation Section
#
# • Explain the Multiply-by-25 shortcut.
#
# • Show why the method works.
#
# • Provide 5 fully worked examples.
#
# Part D — Math League Teaching Strategy
#
# • Provide speed tips, pattern recognition strategies, mental-math shortcuts, and common mistakes students make.
#
# Part E — Teacher Notes
#
# • Provide one paragraph of coaching advice for contest preparation.
#
# After generating all content, compile everything into a single downloadable PDF format (text ready to copy into a word processor).
#
# Output instructions:
#
# - Clean, minimal styling — simple grid, no heavy color blocks.
#
# - Questions run continuously with forced page breaks between sub-tables.
#
# - Questions and Answer key should have a page forced page break.
#
# - Answer key mirrors the same layout as the question tables.
#
# - Answer key runs continuously without forced page breaks between sub-tables.
#
# - Compile everything into a single downloadable PDF.
#
# """

# %% [markdown]
# ### Use the prompt, generated in previous setp, to get the file with questions and answers as a document (.docx) or as PDF file

# %%
"""

Use the Saved Pattern: MathLeague.org Practice Pack Generation for following

As a math teacher who writes MathLeague.org practice materials, create a
complete "Estimation" practice pack.

Follow the PDF file structure provided.

Follow this exact structure:

Part A — 240 Practice Questions (Estimation)

- Add a 1 or 2 line instruction like:
    Instructions: Estimate the value of each expression. Use mental
    math shortcuts and rounding strategies where helpful. Write your
    best estimate in the space provided.

- Use a balanced mix of the following 14 estimation question types:

    Type 1  — Addition & Subtraction:
        (estimate) [a] + [b] - [c]
        e.g. (estimate) 1385 + 1289 - 679

    Type 2  — Two-Factor Multiplication:
        (estimate) [a] × [b]
        e.g. (estimate) 209 × 499

    Type 3  — Three-Factor Multiplication:
        (estimate) [a] × [b] × [c]
        e.g. (estimate) 39 × 49 × 43

    Type 4  — Near-Fraction Multiplication:
        (estimate) [single digit] × [near-unit-fraction number]
        e.g. (estimate) 9 × 428571

    Type 5  — Division:
        (estimate) [large number] ÷ [number]
        e.g. (estimate) 849512 ÷ 169

    Type 6  — Square Root:
        (estimate) √[large number]
        e.g. (estimate) √824892

    Type 7  — Two-Factor Multiplication (mixed size):
        (estimate) [3-digit] × [2-digit]
        e.g. (estimate) 667 × 81

    Type 8  — Decimal Base Power:
        (estimate) [decimal close to whole number] ^ [small n]
        e.g. (estimate) 3.1 ^ 4

    Type 9  — Whole Number Square:
        (estimate) [a] ^ 2
        e.g. (estimate) 333 ^ 2

    Type 10 — Whole Number Higher Power:
        (estimate) [a] ^ [n ≥ 3]
        e.g. (estimate) 333 ^ 4

    Type 11 — Circle Area with Radical Radius:
        (estimate) the area of a circle with radius [a√b] is
        e.g. (estimate) the area of a circle with radius 4√2 is

    Type 12 — Cube Root:
        (estimate) ∛[large number]
        e.g. (estimate) ∛824892

    Type 13 — Product of Square Roots Divided by Power of 10:
        (estimate) (√[a] × √[b]) ÷ 10^[n]
        e.g. (estimate) (√43 × √47) ÷ 10^4

    Type 14 — Product of Squares Divided by Power of 10:
        (estimate) ([a]^2 × [b]^2) ÷ 10^[n]
        e.g. (estimate) (43^2 × 47^2) ÷ 10^4

- Distribute all 14 types as evenly as possible across 240 questions
  (approximately 17 questions per type).
- Include a balanced mix of difficulty levels:
    - Easy: small numbers, straightforward rounding
    - Medium: multi-step rounding required
    - Hard: large numbers, decimals, or nested operations
    - Advanced: combinations requiring multiple estimation strategies
- Format each question exactly like this:
    1.  (estimate) 1385 + 1289 - 679 =
    2.  (estimate) 209 × 499 =
    3.  (estimate) 39 × 49 × 43 =
    4.  (estimate) 9 × 428571 =
    5.  (estimate) 849512 ÷ 169 =
    6.  (estimate) √824892 =
    7.  (estimate) 667 × 81 =
    8.  (estimate) 3.1 ^ 4 =
    9.  (estimate) 333 ^ 2 =
    10. (estimate) 333 ^ 4 =
    11. (estimate) the area of a circle with radius 4√2 is
    12. (estimate) ∛824892 =
    13. (estimate) (√43 × √47) ÷ 10^4 =
    14. (estimate) (43^2 × 47^2) ÷ 10^4 =

- Do NOT repeat the same numbers.
- Do NOT create sequential patterns.
- Mix all 14 question types and difficulty levels throughout.
- Provide space for answer between 2 columns.
- Split questions in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Use markdown grid tables.
  Each table has 15 rows (30 questions total).
  Example:

  | 1.  (estimate) 1385 + 1289 - 679 =          | 16. (estimate) 667 × 81 =                   |
  |---------------------------------------------|---------------------------------------------|
  | 2.  (estimate) 209 × 499 =                   | 17. (estimate) ∛824892 =                    |
  | 3.  (estimate) 39 × 49 × 43 =                | 18. (estimate) 333 ^ 2 =                    |
  | 4.  (estimate) 9 × 428571 =                  | 19. (estimate) (√43 × √47) ÷ 10^4 =        |
  | 5.  (estimate) 849512 ÷ 169 =                | 20. (estimate) (43^2 × 47^2) ÷ 10^4 =      |
  (continue for all 30 questions)

- 8 tables total (Tables 1–8), 30 questions each = 240 total.
- Forced page break between each table.

Part B — Answer Key

- Add a 1 or 2 line instruction like:
    Instructions: Check your estimates below. Each answer shows the
    exact value and acceptable estimation range. Any estimate within
    the acceptable range is correct.

- Provide all 240 answers in order.

- Each answer must show the estimated value and acceptable range:
    1. ≈ 2,000  (acceptable range: 1,900–2,100)

- Format each answer exactly like this:
    1. ≈ {Estimated Answer}  (acceptable: {low}–{high})

- Split answers in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Same two-column, 15-row, 30-answer layout as Part A.
  Example:

  | 1.  ≈ 2,000  (acceptable: 1,900–2,100)      | 16. ≈ 54,000  (acceptable: 52,000–56,000)  |
  |----------------------------------------------|---------------------------------------------|
  | 2.  ≈ 100,000 (acceptable: 95,000–105,000)   | 17. ≈ 94  (acceptable: 90–98)              |
  (continue for all 30 answers)

- 8 tables total (Tables 1–8), 30 answers each = 240 total.
- Answer key runs continuously without forced page breaks
  between sub-tables.
- Forced page break between Part A and Part B.

Part C — Explanation Section

- Explain what mathematical estimation means in a contest context.
- Show the core strategy for each of the 14 question types:
    Type 1  — Round each term to leading digit before
                adding/subtracting.
    Type 2  — Round both factors to nearest round number;
                compensate for rounding error.
    Type 3  — Round all three factors; watch for compounding
                rounding error across three terms.
    Type 4  — Recognize near-unit-fractions
                (e.g. 428571 ≈ 3/7 × 10^6).
    Type 5  — Round dividend and divisor to compatible
                round numbers; simplify the division.
    Type 6  — Bracket between two perfect squares;
                interpolate linearly.
    Type 7  — Round one or both factors to leading digit;
                apply compensation.
    Type 8  — Use binomial expansion
                (a + δ)^n ≈ a^n + n·a^(n-1)·δ for decimal
                bases close to whole numbers.
    Type 9  — Use (a ± δ)^2 = a^2 ± 2aδ + δ^2 shortcut.
    Type 10 — Use logarithm approximation or repeated
                squaring with error tracking.
    Type 11 — Use A = πr^2 with π ≈ 3.14; simplify radical
                radius first (r = a√b → r^2 = a^2 × b).
    Type 12 — Bracket between two perfect cubes;
                interpolate linearly.
    Type 13 — Simplify √a × √b = √(ab) first; divide result
                by the given power of 10.
    Type 14 — Rewrite as (a × b)^2 ÷ 10^n; estimate (a × b)
                first, then square and divide.
- Explain why each strategy works.
- Provide 5 fully worked examples, one each from 5 different
  question types:
    1. (estimate) 1385 + 1289 - 679        (Type 1)
    2. (estimate) 9 × 428571               (Type 4)
    3. (estimate) √824892                  (Type 6)
    4. (estimate) 3.1 ^ 4                  (Type 8)
    5. (estimate) (43^2 × 47^2) ÷ 10^4    (Type 14)

Part D — Math League Teaching Strategy

- Provide speed tips, pattern recognition strategies, mental-math
  shortcuts, and common mistakes students make, including:
    - Over-rounding leading to large errors in multi-step problems
    - Ignoring compensating errors in multi-factor multiplication
    - Misidentifying near-unit-fractions (Type 4)
    - Using wrong π approximation for circle area (Type 11)
    - Confusing square root bracketing with cube root bracketing
      (Types 6 and 12)
    - Misapplying binomial expansion for higher integer powers
      (Types 8 and 10)
    - Forgetting to simplify √a × √b = √(ab) before dividing
      by power of 10 (Type 13)
    - Confusing Type 13 (roots) with Type 14 (squares) and
      applying the wrong simplification strategy
    - Not verifying that the final estimate falls within a
      reasonable acceptable range

Part E — Teacher Notes

- Provide one paragraph of coaching advice for contest preparation
  focused on all 14 estimation problem types commonly seen in Math
  League competitions, including how to train students to instantly
  recognize the question type, select the correct shortcut, and
  produce a reliable estimate within the acceptable range under
  strict time pressure.

Output instructions:
- After generating all content, compile everything into a single
  downloadable PDF format (text ready to copy into a word processor).
- Clean, minimal styling — simple grid, no heavy color blocks.
- Questions run continuously with forced page breaks between sub-tables.
- Questions and Answer Key should have a forced page break between them.
- Answer key mirrors the same layout as the question tables.
- Answer key runs continuously without forced page breaks between
  sub-tables.
- Compile everything into a single downloadable PDF.

"""

# %% [markdown]
# ## Subtraction_Multiple_Numbers
#
#
#
# *   File: Subtraction_Multiple_Numbers_Practice_Pack_

# %% [markdown]
# ### Generate the Prompt from given Question Sample

# %% [markdown]
# > Prompt
#
# >
# for the given question:
#
# ```
# """
#
#   1. 128 - 45 - 67 + 89 =
#   1. 128 - 45 =
#   1. 128 - 15 - 67 =
#   1. 12844 - 145 - 67 - 89 =
#   1. 21000 - 1280 - 14545 =
#   1. 1286 - 455 - 670 =
#
# """
#
#
#
#
#
#
# ```
#
# Generate a prompt in the Given format:
#
# ```
# """
# Use the Saved Pattern: MathLeague.org Practice Pack Generation for following
#
# As a math teacher who writes MathLeague.org practice materials, create a complete “Multiply by 25” practice pack.
#
# Follow the PDF file structure provided.
#
# Follow this exact structure:
#
# Part A — 240 Practice Questions (Multiply by 25)
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Multiply each number by 25. Use the shortcut method (divide by 4, then multiply by 100) where helpful.
#
#     Write your answer in the space provided.
#
# • Use only 2-digit, 3-digit, 4-digit, 5-digit, or decimal numbers.
#
# • All questions must be of the form (number × 25) or (25 × number).
#
# • Include a balanced mix of whole numbers and decimals.
#
# • Format each question exactly like this:
#
#     1. 128 × 25 =
#
#     2. 25 × 1,284 =
#
#     3. 11,438 × 25 =
#
# • Do NOT repeat numbers.
#
# • Do NOT create sequential patterns.
#
# • Mix difficulty levels.
#
# • Provide space for answer between 2 columns.
#
# • Split questions in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Use markdown grid tables. Each table has 15 rows (30 questions total).
#
#   Example:
#
#   | 1. 128 × 25 = | 16. 25 × 34.5 = |
#
#   |----------------|------------------|
#
#   | 2. 25 × 5,234 = | 17. 729 × 25 = |
#
#   (continue for all 30 questions)
#
# • 8 tables total (Tables 1–8).
#
# Part B — Answer Key
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Check your answers below. Answers are in order. Use the shortcut to check your work.
#
# • Provide all 240 answers in order.
#
# • Format each answer exactly like this:
#
#     1. {Answer}
#
# • Split answers in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Same two-column, 15-row, 30-answer table layout as Part A.
#
#   Example:
#
#   | 1. 3200 | 16. 862.5 |
#
#   |---------|----------|
#
#   | 2. 130850 | 17. 18225 |
#
# • 8 tables total (Tables 1–8).
#
# Part C — Explanation Section
#
# • Explain the Multiply-by-25 shortcut.
#
# • Show why the method works.
#
# • Provide 5 fully worked examples.
#
# Part D — Math League Teaching Strategy
#
# • Provide speed tips, pattern recognition strategies, mental-math shortcuts, and common mistakes students make.
#
# Part E — Teacher Notes
#
# • Provide one paragraph of coaching advice for contest preparation.
#
# After generating all content, compile everything into a single downloadable PDF format (text ready to copy into a word processor).
#
# Output instructions:
#
# - Clean, minimal styling — simple grid, no heavy color blocks.
#
# - Questions run continuously with forced page breaks between sub-tables.
#
# - Questions and Answer key should have a page forced page break.
#
# - Answer key mirrors the same layout as the question tables.
#
# - Answer key runs continuously without forced page breaks between sub-tables.
#
# - Compile everything into a single downloadable PDF.
#
# """
#
# ```

# %% [markdown]
# ### Use the prompt, generated in previous setp, to get the file with questions and answers as a document (.docx) or as PDF file

# %%
"""

Use the Saved Pattern: MathLeague.org Practice Pack Generation for following

As a math teacher who writes MathLeague.org practice materials, create a
complete "Substracting Multiple Numbers (Mental Subtraction)" practice pack.

Follow the PDF file structure provided.

Follow this exact structure:

Part A — 240 Practice Questions (Substracting Multiple Numbers / Mental Subtraction)

- Add a 1 or 2 line instruction like:
    Instructions: Subtract the numbers mentally. Look for opportunities
    to regroup, compensate, or subtract from a round number to speed up
    your calculation. Write your answer in the space provided.

- Use only 2-digit, 3-digit, 4-digit, or 5-digit whole numbers.

- All questions must be of the form:
    (num1 - num2) or
    (num1 - num2 - num3) or
    (num1 - num2 - num3 - num4) or
    (num1 - num2 + num3) or
    (num1 - num2 - num3 + num4)

- All questions must be subtraction problems using the following
  sub-types in a balanced mix:

    Sub-type 1: Two numbers (2-digit only)
        e.g. 89 - 45 =

    Sub-type 2: Two numbers (mixed 2-digit and 3-digit)
        e.g. 128 - 45 =

    Sub-type 3: Three numbers (2-digit and 3-digit mix,
                subtraction only)
        e.g. 128 - 15 - 67 =

    Sub-type 4: Four numbers (2-digit and 3-digit mix,
                subtraction only)
        e.g. 128 - 45 - 67 - 89 =

    Sub-type 5: Mixed addition and subtraction
                (2-digit and 3-digit mix)
        e.g. 128 - 45 - 67 + 89 =

    Sub-type 6: Two numbers (3-digit and 4-digit or 5-digit mix)
        e.g. 21,000 - 1,280 - 14,545 =

    Sub-type 7: Three numbers (3-digit and 4-digit mix,
                subtraction only)
        e.g. 1,286 - 455 - 670 =

    Sub-type 8: Four numbers (4-digit and 5-digit mix,
                subtraction only)
        e.g. 12,844 - 145 - 67 - 89 =

- Distribute all 8 sub-types evenly across 240 questions
  (30 questions per sub-type).
- Include a balanced mix of difficulty levels:
    - Easy: two small numbers, no borrowing required
    - Medium: two or three numbers, one or two borrows
    - Hard: three or four numbers, multiple borrows
    - Advanced: four numbers with large digits, multiple
      borrows across all columns
- Format each question exactly like this:
    1. 128 - 45 - 67 + 89 =
    2. 128 - 45 =
    3. 128 - 15 - 67 =
    4. 12,844 - 145 - 67 - 89 =
    5. 21,000 - 1,280 - 14,545 =
    6. 1,286 - 455 - 670 =

- Do NOT repeat number combinations.
- Do NOT create sequential patterns.
- Ensure all answers are positive whole numbers.
- Mix sub-types and difficulty levels throughout.
- Provide space for answer between 2 columns.
- Split questions in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Use markdown grid tables.
  Each table has 15 rows (30 questions total).
  Example:

  | 1.  128 - 45 - 67 + 89 =       | 16. 1,286 - 455 - 670 =      |
  |---------------------------------|-------------------------------|
  | 2.  128 - 45 =                  | 17. 12,844 - 145 - 67 =      |
  | 3.  128 - 15 - 67 =             | 18. 21,000 - 1,280 - 14,545 =|
  | 4.  12,844 - 145 - 67 - 89 =    | 19. 456 - 78 - 23 =          |
  | 5.  21,000 - 1,280 - 14,545 =   | 20. 3,712 - 889 - 54 =       |
  (continue for all 30 questions)

- 8 tables total (Tables 1–8), 30 questions each = 240 total.
- Forced page break between each table.

Part B — Answer Key

- Add a 1 or 2 line instruction like:
    Instructions: Check your answers below. Answers are listed in
    order. Look for mental math shortcuts you may have missed.

- Provide all 240 answers in order.

- Format each answer exactly like this:
    1. {Answer}

- Split answers in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Same two-column, 15-row, 30-answer layout as Part A.
  Example:

  | 1.  105          | 16. 161          |
  |------------------|------------------|
  | 2.  83           | 17. 12,632       |
  | 3.  46           | 18. 5,175        |
  | 4.  12,543       | 19. 355          |
  | 5.  5,175        | 20. 2,769        |
  (continue for all 30 answers)

- 8 tables total (Tables 1–8), 30 answers each = 240 total.
- Answer key runs continuously without forced page breaks
  between sub-tables.
- Forced page break between Part A and Part B.

Part C — Explanation Section

- Explain the mental subtraction strategies:
    - Strategy 1: Subtract from a Round Number
        Round the subtrahend up to nearest 10/100/1,000,
        subtract, then adjust.
        e.g. 128 - 45: think 128 - 50 = 78, then +5 = 83
    - Strategy 2: Left-to-Right Subtraction
        Subtract the largest place values first, then work right.
        e.g. 1,286 - 455 - 670:
             1,286 - 400 - 600 = 286
             286 - 55 - 70 = 161
    - Strategy 3: Compensation
        Round one subtrahend up, add back the difference at end.
        e.g. 128 - 15 - 67:
             128 - 20 - 70 = 38, then +5 +3 = 46
    - Strategy 4: Combined Add & Subtract (Mixed Signs)
        Group all additions first, then all subtractions,
        and combine the two totals.
        e.g. 128 - 45 - 67 + 89:
             (128 + 89) - (45 + 67) = 217 - 112 = 105
    - Strategy 5: Counting Up (for close numbers)
        Instead of subtracting, count up from the smaller
        number to the larger.
        e.g. 21,000 - 1,280 - 14,545:
             21,000 - 14,545 = 6,455; 6,455 - 1,280 = 5,175
- Show why each strategy works.
- Provide 5 fully worked examples:
    1. 128 - 45 - 67 + 89   (mixed signs, grouping strategy)
    2. 128 - 45              (two numbers, compensation)
    3. 128 - 15 - 67         (three numbers, left-to-right)
    4. 12,844 - 145 - 67 - 89 (large numbers, sequential)
    5. 21,000 - 1,280 - 14,545 (round number anchor)

Part D — Math League Teaching Strategy

- Provide speed tips, pattern recognition strategies, mental-math
  shortcuts, and common mistakes students make, including:
    - Borrowing errors when subtracting across zeros
      (e.g. 21,000 - 14,545)
    - Losing track of signs in mixed addition/subtraction problems
    - Subtracting in wrong order and getting a negative result
    - Forgetting to adjust after rounding a subtrahend
    - Miscounting borrows across multiple columns
    - Confusing compensation direction
      (adding back vs. subtracting back)
    - Not checking that the final answer is positive

Part E — Teacher Notes

- Provide one paragraph of coaching advice for contest preparation
  focused on mental subtraction problems commonly seen in Math League
  competitions, including how to train students to identify the
  fastest strategy for each sub-type, handle borrowing across zeros
  confidently, and manage mixed-sign problems accurately under
  time pressure.

Output instructions:
- After generating all content, compile everything into a single
  downloadable PDF format (text ready to copy into a word processor).
- Clean, minimal styling — simple grid, no heavy color blocks.
- Questions run continuously with forced page breaks between sub-tables.
- Questions and Answer Key should have a forced page break between them.
- Answer key mirrors the same layout as the question tables.
- Answer key runs continuously without forced page breaks between
  sub-tables.
- Compile everything into a single downloadable PDF.

"""

# %% [markdown]
# ## Addition_Multiple_Numbers
#
#
#
# *   File:Addition_Practice_Pack_

# %% [markdown]
# ### Generate the Prompt from given Question Sample

# %% [markdown]
# > Prompt
#
# >
#
# for the given question:
#
# ```
# """
#
#   1. 128 + 45 + 67 + 89 =
#   1. 128 + 45 =
#   1. 128 + 45 + 67 =
#   1. 12844 + 145 + 67 + 89 =
#   1. 1280 + 14545 =
#   1. 1286 + 455 + 670 =
#
# """
#
#
#
#
#
# ```
#
# Generate a prompt in the Given format:
#
# ```
# """
#
# Use the Saved Pattern: MathLeague.org Practice Pack Generation for following
#
# As a math teacher who writes MathLeague.org practice materials, create a
# complete "Adding Multiple Numbers" practice pack.
#
# Follow the PDF file structure provided.
#
# Follow this exact structure:
#
# Part A — 240 Practice Questions (Adding Multiple Numbers / Mental Addition)
#
# - Add a 1 or 2 line instruction like:
#     Instructions: Add the numbers mentally. Look for pairs that make
#     round numbers (e.g. numbers summing to 100 or 1,000) to speed up
#     your calculation. Write your answer in the space provided.
#
# - Use only 2-digit, 3-digit, 4-digit, 5-digit, or decimal numbers.
#
# - All questions must be of the form (num1 + num2) or (num1 + num2 + num3) or (num1 + num2 + num3 + num4) or (num1 + num2 + num3 + num4 + num5).
#
# - All questions must be addition problems using the following
#   sub-types in a balanced mix:
#
#     Sub-type 1: Two 2-digit numbers
#         e.g. 128 + 45 =  ← treat as add two numbers ≤ 3 digits
#         e.g. 128 + 45 =
#
#     Sub-type 2: Two numbers (mixed 2-digit and 3-digit)
#         e.g. 128 + 45 =
#
#     Sub-type 3: Three numbers (2-digit and 3-digit mix)
#         e.g. 128 + 45 + 67 =
#
#     Sub-type 4: Four numbers (2-digit and 3-digit mix)
#         e.g. 128 + 45 + 67 + 89 =
#
#     Sub-type 5: Two numbers (3-digit and 4-digit mix)
#         e.g. 1,280 + 14,545 =
#
#     Sub-type 6: Three numbers (3-digit and 4-digit mix)
#         e.g. 1,286 + 455 + 670 =
#
#     Sub-type 7: Four numbers (4-digit and 5-digit mix)
#         e.g. 12,844 + 145 + 67 + 89 =
#
# - Distribute all 7 sub-types evenly across 240 questions
#   (approximately 34 questions per sub-type).
# - Include a balanced mix of difficulty levels:
#     - Easy: two small numbers, no carrying required
#     - Medium: two or three numbers, one or two carries
#     - Hard: three or four numbers, multiple carries
#     - Advanced: four numbers with large digits, multiple
#       carries across all columns
# - Format each question exactly like this:
#     1. 128 + 45 + 67 + 89 =
#     2. 128 + 45 =
#     3. 128 + 45 + 67 =
#     4. 12,844 + 145 + 67 + 89 =
#     5. 1,280 + 14,545 =
#     6. 1,286 + 455 + 670 =
#
# - Do NOT repeat number combinations.
# - Do NOT create sequential patterns.
# - Mix sub-types and difficulty levels throughout.
# - Provide space for answer between 2 columns.
# - Split questions in 2 columns like (1 with 16, 2 with 17, etc.)
#
# - TABLE STRUCTURE: Use markdown grid tables.
#   Each table has 15 rows (30 questions total).
#   Example:
#
#   | 1.  128 + 45 + 67 + 89 =      | 16. 1,286 + 455 + 670 =     |
#   |--------------------------------|-----------------------------|
#   | 2.  128 + 45 =                 | 17. 12,844 + 145 + 67 =     |
#   | 3.  128 + 45 + 67 =            | 18. 1,280 + 14,545 =        |
#   | 4.  12,844 + 145 + 67 + 89 =   | 19. 456 + 78 + 23 =         |
#   | 5.  1,280 + 14,545 =           | 20. 3,712 + 889 + 54 =      |
#   (continue for all 30 questions)
#
# - 8 tables total (Tables 1–8), 30 questions each = 240 total.
# - Forced page break between each table.
#
# Part B — Answer Key
#
# - Add a 1 or 2 line instruction like:
#     Instructions: Check your answers below. Answers are listed in
#     order. Look for mental math shortcuts you may have missed.
#
# - Provide all 240 answers in order.
#
# - Format each answer exactly like this:
#     1. {Answer}
#
# - Split answers in 2 columns like (1 with 16, 2 with 17, etc.)
#
# - TABLE STRUCTURE: Same two-column, 15-row, 30-answer layout as Part A.
#   Example:
#
#   | 1.  329          | 16. 2,411        |
#   |------------------|------------------|
#   | 2.  173          | 17. 13,056       |
#   | 3.  240          | 18. 15,825       |
#   | 4.  13,145       | 19. 557          |
#   | 5.  15,825       | 20. 4,655        |
#   (continue for all 30 answers)
#
# - 8 tables total (Tables 1–8), 30 answers each = 240 total.
# - Answer key runs continuously without forced page breaks
#   between sub-tables.
# - Forced page break between Part A and Part B.
#
# Part C — Explanation Section
#
# - Explain the mental addition strategies:
#     - Strategy 1: Make-a-Round-Number
#         Look for pairs that sum to 10, 100, or 1,000 first.
#         e.g. 128 + 45 + 67 + 89:
#              (128 + 72) would be 200, but 45 + 55 = 100 →
#              group strategically before adding.
#     - Strategy 2: Left-to-Right Addition
#         Add the largest place values first, then work right.
#         e.g. 1,286 + 455 + 670:
#              1,000 + 400 + 600 = 2,000
#              200 + 50 + 70 = 320
#              6 + 5 + 0 = 11
#              Total = 2,331
#     - Strategy 3: Compensation
#         Round one addend up, subtract the difference at the end.
#         e.g. 128 + 45: round 45 to 50, add 178, subtract 5 = 173
#     - Strategy 4: Grouping for Efficiency
#         In four-addend problems, pair numbers that are easy
#         to add first, then combine the two subtotals.
#         e.g. 128 + 45 + 67 + 89:
#              (128 + 89) + (45 + 67) = 217 + 112 = 329
# - Show why each strategy works.
# - Provide 5 fully worked examples:
#     1. 128 + 45 + 67 + 89   (four numbers, grouping strategy)
#     2. 128 + 45              (two numbers, compensation)
#     3. 128 + 45 + 67         (three numbers, left-to-right)
#     4. 12,844 + 145 + 67 + 89 (large numbers, grouping)
#     5. 1,286 + 455 + 670    (three numbers, round-number pairs)
#
# Part D — Math League Teaching Strategy
#
# - Provide speed tips, pattern recognition strategies, mental-math
#   shortcuts, and common mistakes students make, including:
#     - Missing obvious round-number pairs hidden in the list
#     - Adding strictly left-to-right without looking ahead
#     - Carrying errors when summing 3 or 4 numbers in a column
#     - Forgetting to include all addends when grouping
#     - Confusing the compensation adjustment direction
#       (adding too much vs. too little)
#     - Losing track of place value when mixing 3-digit and
#       5-digit numbers in the same problem
#
# Part E — Teacher Notes
#
# - Provide one paragraph of coaching advice for contest preparation
#   focused on mental addition problems commonly seen in Math League
#   competitions, including how to train students to scan all addends
#   before calculating, recognize round-number pairs instantly, and
#   build accuracy with multi-addend problems under time pressure.
#
# Output instructions:
# - After generating all content, compile everything into a single
#   downloadable PDF format (text ready to copy into a word processor).
# - Clean, minimal styling — simple grid, no heavy color blocks.
# - Questions run continuously with forced page breaks between sub-tables.
# - Questions and Answer Key should have a forced page break between them.
# - Answer key mirrors the same layout as the question tables.
# - Answer key runs continuously without forced page breaks between
#   sub-tables.
# - Compile everything into a single downloadable PDF.
#
# """
#
#
#
#
#
# ```

# %% [markdown]
# ### Use the prompt, generated in previous setp, to get the file with questions and answers as a document (.docx) or as PDF file

# %%
"""

Use the Saved Pattern: MathLeague.org Practice Pack Generation for following

As a math teacher who writes MathLeague.org practice materials, create a
complete "Adding Multiple Numbers" practice pack.

Follow the PDF file structure provided.

Follow this exact structure:

Part A — 240 Practice Questions (Adding Multiple Numbers / Mental Addition)

- Add a 1 or 2 line instruction like:
    Instructions: Add the numbers mentally. Look for pairs that make
    round numbers (e.g. numbers summing to 100 or 1,000) to speed up
    your calculation. Write your answer in the space provided.

- Use only 2-digit, 3-digit, 4-digit, or 5-digit whole numbers.

- All questions must be of the form:
    (num1 + num2) or
    (num1 + num2 + num3) or
    (num1 + num2 + num3 + num4) or
    (num1 + num2 + num3 + num4 + num5)

- All questions must be addition problems using the following
  sub-types in a balanced mix:

    Sub-type 1: Two numbers (2-digit only)
        e.g. 45 + 67 =

    Sub-type 2: Two numbers (mixed 2-digit and 3-digit)
        e.g. 128 + 45 =

    Sub-type 3: Three numbers (2-digit and 3-digit mix)
        e.g. 128 + 45 + 67 =

    Sub-type 4: Four numbers (2-digit and 3-digit mix)
        e.g. 128 + 45 + 67 + 89 =

    Sub-type 5: Two numbers (3-digit and 4-digit or 5-digit mix)
        e.g. 1,280 + 14,545 =

    Sub-type 6: Three numbers (3-digit and 4-digit mix)
        e.g. 1,286 + 455 + 670 =

    Sub-type 7: Four numbers (4-digit and 5-digit mix)
        e.g. 12,844 + 145 + 67 + 89 =

- Distribute all 7 sub-types evenly across 240 questions
  (approximately 34 questions per sub-type).
- Include a balanced mix of difficulty levels:
    - Easy: two small numbers, no carrying required
    - Medium: two or three numbers, one or two carries
    - Hard: three or four numbers, multiple carries
    - Advanced: four or five numbers with large digits,
      multiple carries across all columns
- Format each question exactly like this:
    1. 128 + 45 + 67 + 89 =
    2. 128 + 45 =
    3. 128 + 45 + 67 =
    4. 12,844 + 145 + 67 + 89 =
    5. 1,280 + 14,545 =
    6. 1,286 + 455 + 670 =

- Do NOT repeat number combinations.
- Do NOT create sequential patterns.
- Mix sub-types and difficulty levels throughout.
- Provide space for answer between 2 columns.
- Split questions in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Use markdown grid tables.
  Each table has 15 rows (30 questions total).
  Example:

  | 1.  128 + 45 + 67 + 89 =       | 16. 1,286 + 455 + 670 =      |
  |---------------------------------|-------------------------------|
  | 2.  128 + 45 =                  | 17. 12,844 + 145 + 67 =      |
  | 3.  128 + 45 + 67 =             | 18. 1,280 + 14,545 =         |
  | 4.  12,844 + 145 + 67 + 89 =    | 19. 456 + 78 + 23 =          |
  | 5.  1,280 + 14,545 =            | 20. 3,712 + 889 + 54 =       |
  (continue for all 30 questions)

- 8 tables total (Tables 1–8), 30 questions each = 240 total.
- Forced page break between each table.

Part B — Answer Key

- Add a 1 or 2 line instruction like:
    Instructions: Check your answers below. Answers are listed in
    order. Look for mental math shortcuts you may have missed.

- Provide all 240 answers in order.

- Format each answer exactly like this:
    1. {Answer}

- Split answers in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Same two-column, 15-row, 30-answer layout as Part A.
  Example:

  | 1.  329          | 16. 2,411        |
  |------------------|------------------|
  | 2.  173          | 17. 13,056       |
  | 3.  240          | 18. 15,825       |
  | 4.  13,145       | 19. 557          |
  | 5.  15,825       | 20. 4,655        |
  (continue for all 30 answers)

- 8 tables total (Tables 1–8), 30 answers each = 240 total.
- Answer key runs continuously without forced page breaks
  between sub-tables.
- Forced page break between Part A and Part B.

Part C — Explanation Section

- Explain the mental addition strategies:
    - Strategy 1: Make-a-Round-Number
        Look for pairs that sum to 10, 100, or 1,000 first.
        e.g. 128 + 45 + 67 + 89:
             group (45 + 67) = 112, then (128 + 89) = 217,
             then 217 + 112 = 329
    - Strategy 2: Left-to-Right Addition
        Add the largest place values first, then work right.
        e.g. 1,286 + 455 + 670:
             1,000 + 400 + 600 = 2,000
             200 + 50 + 70 = 320
             6 + 5 + 0 = 11
             Total = 2,331
    - Strategy 3: Compensation
        Round one addend up, subtract the difference at the end.
        e.g. 128 + 45: round 45 → 50, get 178, subtract 5 = 173
    - Strategy 4: Grouping for Efficiency
        In four-addend problems, pair numbers that are easy
        to add first, then combine the two subtotals.
        e.g. 128 + 45 + 67 + 89:
             (128 + 89) + (45 + 67) = 217 + 112 = 329
- Show why each strategy works.
- Provide 5 fully worked examples:
    1. 128 + 45 + 67 + 89   (four numbers, grouping strategy)
    2. 128 + 45              (two numbers, compensation)
    3. 128 + 45 + 67         (three numbers, left-to-right)
    4. 12,844 + 145 + 67 + 89 (large numbers, grouping)
    5. 1,286 + 455 + 670    (three numbers, round-number pairs)

Part D — Math League Teaching Strategy

- Provide speed tips, pattern recognition strategies, mental-math
  shortcuts, and common mistakes students make, including:
    - Missing obvious round-number pairs hidden in the list
    - Adding strictly left-to-right without looking ahead
    - Carrying errors when summing 3 or 4 numbers in a column
    - Forgetting to include all addends when grouping
    - Confusing the compensation adjustment direction
      (adding too much vs. too little)
    - Losing track of place value when mixing 3-digit and
      5-digit numbers in the same problem

Part E — Teacher Notes

- Provide one paragraph of coaching advice for contest preparation
  focused on mental addition problems commonly seen in Math League
  competitions, including how to train students to scan all addends
  before calculating, recognize round-number pairs instantly, and
  build accuracy with multi-addend problems under time pressure.

Output instructions:
- After generating all content, compile everything into a single
  downloadable PDF format (text ready to copy into a word processor).
- Clean, minimal styling — simple grid, no heavy color blocks.
- Questions run continuously with forced page breaks between sub-tables.
- Questions and Answer Key should have a forced page break between them.
- Answer key mirrors the same layout as the question tables.
- Answer key runs continuously without forced page breaks between
  sub-tables.
- Compile everything into a single downloadable PDF.

"""

# %% [markdown]
# ## Double_and_Half_Method_Multiplication
#
#
#
# *   File: Double_and_Half_Method_Multiplication_Practice_Pack_

# %% [markdown]
# ### Generate the Prompt from given Question Sample

# %% [markdown]
# > Prompt
#
# >
# for the given question:
#
# ```
# """
#
#   1. 15 × 12 =
#   2. 35 × 114 =
#   3. 45 × 16 =
#   4. 25 × 1824 =
#   5. 26 × 15 =
#
# """
#
#
#
#
# ```
#
# Generate a prompt in the Given format:
#
# ```
# """
#
# Use the Saved Pattern: MathLeague.org Practice Pack Generation for following
#
# As a math teacher who writes MathLeague.org practice materials, create a complete “Multiply by 25” practice pack.
#
# Follow the PDF file structure provided.
#
# Follow this exact structure:
#
# Part A — 240 Practice Questions (Multiply by 25)
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Multiply each number by 25. Use the shortcut method (divide by 4, then multiply by 100) where helpful.
#
#     Write your answer in the space provided.
#
# • Use only 2-digit, 3-digit, 4-digit, 5-digit, or decimal numbers.
#
# • All questions must be of the form (number × 25) or (25 × number).
#
# • Include a balanced mix of whole numbers and decimals.
#
# • Format each question exactly like this:
#
#     1. 128 × 25 =
#
#     2. 25 × 1,284 =
#
#     3. 11,438 × 25 =
#
# • Do NOT repeat numbers.
#
# • Do NOT create sequential patterns.
#
# • Mix difficulty levels.
#
# • Provide space for answer between 2 columns.
#
# • Split questions in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Use markdown grid tables. Each table has 15 rows (30 questions total).
#
#   Example:
#
#   | 1. 128 × 25 = | 16. 25 × 34.5 = |
#
#   |----------------|------------------|
#
#   | 2. 25 × 5,234 = | 17. 729 × 25 = |
#
#   (continue for all 30 questions)
#
# • 8 tables total (Tables 1–8).
#
# Part B — Answer Key
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Check your answers below. Answers are in order. Use the shortcut to check your work.
#
# • Provide all 240 answers in order.
#
# • Format each answer exactly like this:
#
#     1. {Answer}
#
# • Split answers in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Same two-column, 15-row, 30-answer table layout as Part A.
#
#   Example:
#
#   | 1. 3200 | 16. 862.5 |
#
#   |---------|----------|
#
#   | 2. 130850 | 17. 18225 |
#
# • 8 tables total (Tables 1–8).
#
# Part C — Explanation Section
#
# • Explain the Multiply-by-25 shortcut.
#
# • Show why the method works.
#
# • Provide 5 fully worked examples.
#
# Part D — Math League Teaching Strategy
#
# • Provide speed tips, pattern recognition strategies, mental-math shortcuts, and common mistakes students make.
#
# Part E — Teacher Notes
#
# • Provide one paragraph of coaching advice for contest preparation.
#
# After generating all content, compile everything into a single downloadable PDF format (text ready to copy into a word processor).
#
# Output instructions:
#
# - Clean, minimal styling — simple grid, no heavy color blocks.
#
# - Questions run continuously with forced page breaks between sub-tables.
#
# - Questions and Answer key should have a page forced page break.
#
# - Answer key mirrors the same layout as the question tables.
#
# - Answer key runs continuously without forced page breaks between sub-tables.
#
# - Compile everything into a single downloadable PDF.
#
# """
#
#
#
#
# ```

# %% [markdown]
# ### Use the prompt, generated in previous setp, to get the file with questions and answers as a document (.docx) or as PDF file

# %%
"""

Use the Saved Pattern: MathLeague.org Practice Pack Generation for following

As a math teacher who writes MathLeague.org practice materials, create a
complete "Double And Half Method of Multiplication (Multiply Two Numbers Ending in 5)" practice pack.

Follow the PDF file structure provided.

Follow this exact structure:

Part A — 240 Practice Questions (Multiply Two Numbers Ending in 5)

- Add a 1 or 2 line instruction like:
    Instructions: Multiply each pair of numbers. At least one number
    in each pair ends in 5. Use the shortcut method where helpful.
    Write your answer in the space provided.

- Use only 2-digit, 3-digit, 4-digit, or 5-digit whole numbers.

- All questions must be of the form ([a] × [b]) where:
    - At least one number in every pair ends in 5
    - Both numbers may end in 5 (e.g. 15 × 25, 35 × 45)
    - Or only one number ends in 5 (e.g. 15 × 12, 35 × 114)

- Include a balanced mix across these sub-types:
    - Sub-type 1: both numbers are 2-digit, one ends in 5
        e.g. 15 × 12, 35 × 48
    - Sub-type 2: both numbers are 2-digit, both end in 5
        e.g. 15 × 25, 35 × 45
    - Sub-type 3: one 2-digit (ends in 5) × one 3-digit
        e.g. 35 × 114, 45 × 228
    - Sub-type 4: one 2-digit (ends in 5) × one 4-digit
        e.g. 25 × 1,824, 45 × 3,612
    - Sub-type 5: one 3-digit (ends in 5) × one 2-digit
        e.g. 125 × 16, 315 × 24
    - Sub-type 6: one 3-digit (ends in 5) × one 3-digit
        e.g. 225 × 114, 445 × 316

- Format each question exactly like this:
    1. 15 × 12 =
    2. 35 × 114 =
    3. 45 × 16 =
    4. 25 × 1,824 =

- Do NOT repeat number pairs.
- Do NOT create sequential patterns.
- Mix sub-types and difficulty levels throughout.
- Provide space for answer between 2 columns.
- Split questions in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Use markdown grid tables.
  Each table has 15 rows (30 questions total).
  Example:

  | 1.  15 × 12 =        | 16. 45 × 228 =      |
  |----------------------|---------------------|
  | 2.  35 × 114 =       | 17. 25 × 1,824 =    |
  | 3.  45 × 16 =        | 18. 125 × 36 =      |
  | 4.  25 × 1,824 =     | 19. 315 × 24 =      |
  | 5.  15 × 25 =        | 20. 35 × 45 =       |
  (continue for all 30 questions)

- 8 tables total (Tables 1–8), 30 questions each = 240 total.
- Forced page break between each table.

Part B — Answer Key

- Add a 1 or 2 line instruction like:
    Instructions: Check your answers below. Answers are listed in order.
    Use the shortcut method to verify your work.

- Provide all 240 answers in order.

- Format each answer exactly like this:
    1. {Answer}

- Split answers in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Same two-column, 15-row, 30-answer layout as Part A.
  Example:

  | 1.  180          | 16. 10,260        |
  |------------------|-------------------|
  | 2.  3,990        | 17. 45,600        |
  | 3.  720          | 18. 4,500         |
  | 4.  45,600       | 19. 7,560         |
  | 5.  375          | 20. 1,575         |
  (continue for all 30 answers)

- 8 tables total (Tables 1–8), 30 answers each = 240 total.
- Answer key runs continuously without forced page breaks
  between sub-tables.
- Forced page break between Part A and Part B.

Part C — Explanation Section

- Explain the shortcut for multiplying numbers ending in 5:
    - Core method when BOTH numbers end in 5:
        Multiply the tens digits together, add half their sum,
        then append 25.
        e.g. 35 × 45: (3×4) + (3+4)/2 = 12 + 3.5 → not whole,
        use: (35 × 45) = (40 × 40) - (5 × 5) = 1600 - 25 = 1575
    - Core method when ONE number ends in 5:
        Split the number ending in 5 as (n × 10 + 5),
        distribute and simplify.
        e.g. 35 × 114 = (30 × 114) + (5 × 114)
                      = 3,420 + 570 = 3,990
    - Alternative shortcut: multiply by (n + 0.5) × 10
        e.g. 35 × 114 = 3.5 × 1,140 = 3,990
- Show why each method works.
- Show how to scale up for 3-digit and 4-digit combinations.
- Provide 5 fully worked examples:
    1. 15 × 12     (2-digit × 2-digit, one ends in 5)
    2. 35 × 114    (2-digit × 3-digit)
    3. 45 × 16     (2-digit × 2-digit)
    4. 25 × 1,824  (2-digit × 4-digit)
    5. 315 × 24    (3-digit ends in 5 × 2-digit)

Part D — Math League Teaching Strategy

- Provide speed tips, pattern recognition strategies, mental-math
  shortcuts, and common mistakes students make, including:
    - Forgetting to distribute correctly when splitting the
      number ending in 5
    - Misapplying the "both end in 5" shortcut to cases where
      only one number ends in 5
    - Errors when scaling to 3-digit or 4-digit numbers
    - Confusing this shortcut with the × 25 or × 125 shortcuts
    - Miscounting zeros when using the (n + 0.5) × 10 method

Part E — Teacher Notes

- Provide one paragraph of coaching advice for contest preparation
  focused on multiplying numbers ending in 5, as commonly seen in
  Math League competitions, including how to train students to
  instantly identify which shortcut applies (both end in 5 vs.
  only one ends in 5) and how to build accuracy with larger
  number combinations under time pressure.

Output instructions:
- After generating all content, compile everything into a single
  downloadable PDF format (text ready to copy into a word processor).
- Clean, minimal styling — simple grid, no heavy color blocks.
- Questions run continuously with forced page breaks between sub-tables.
- Questions and Answer Key should have a forced page break between them.
- Answer key mirrors the same layout as the question tables.
- Answer key runs continuously without forced page breaks between
  sub-tables.
- Compile everything into a single downloadable PDF.

"""

# %% [markdown]
# ## Multiply_by_125
#
#
#
# *   File: Multiply_by_125_Practice_Pack

# %% [markdown]
# ### Generate the Prompt from given Question Sample

# %% [markdown]
# > Prompt
#
# >
# for the given question:
#
# ```
# """
#
#   1. 128 × 125 =
#
#   1. 1284 × 125 =
#
#   1. 12438 × 125 =
#
#   1. 12.5 * 125 =
#
#   1. 125 * 3.5 =
#
# """
#
#
#
# ```
#
# Generate a prompt in the Given format:
#
# ```
# """
#
# Use the Saved Pattern: MathLeague.org Practice Pack Generation for following
#
# As a math teacher who writes MathLeague.org practice materials, create a complete “Multiply by 25” practice pack.
#
# Follow the PDF file structure provided.
#
# Follow this exact structure:
#
# Part A — 240 Practice Questions (Multiply by 25)
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Multiply each number by 25. Use the shortcut method (divide by 4, then multiply by 100) where helpful.
#
#     Write your answer in the space provided.
#
# • Use only 2-digit, 3-digit, 4-digit, 5-digit, or decimal numbers.
#
# • All questions must be of the form (number × 25) or (25 × number).
#
# • Include a balanced mix of whole numbers and decimals.
#
# • Format each question exactly like this:
#
#     1. 128 × 25 =
#
#     2. 25 × 1,284 =
#
#     3. 11,438 × 25 =
#
# • Do NOT repeat numbers.
#
# • Do NOT create sequential patterns.
#
# • Mix difficulty levels.
#
# • Provide space for answer between 2 columns.
#
# • Split questions in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Use markdown grid tables. Each table has 15 rows (30 questions total).
#
#   Example:
#
#   | 1. 128 × 25 = | 16. 25 × 34.5 = |
#
#   |----------------|------------------|
#
#   | 2. 25 × 5,234 = | 17. 729 × 25 = |
#
#   (continue for all 30 questions)
#
# • 8 tables total (Tables 1–8).
#
# Part B — Answer Key
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Check your answers below. Answers are in order. Use the shortcut to check your work.
#
# • Provide all 240 answers in order.
#
# • Format each answer exactly like this:
#
#     1. {Answer}
#
# • Split answers in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Same two-column, 15-row, 30-answer table layout as Part A.
#
#   Example:
#
#   | 1. 3200 | 16. 862.5 |
#
#   |---------|----------|
#
#   | 2. 130850 | 17. 18225 |
#
# • 8 tables total (Tables 1–8).
#
# Part C — Explanation Section
#
# • Explain the Multiply-by-25 shortcut.
#
# • Show why the method works.
#
# • Provide 5 fully worked examples.
#
# Part D — Math League Teaching Strategy
#
# • Provide speed tips, pattern recognition strategies, mental-math shortcuts, and common mistakes students make.
#
# Part E — Teacher Notes
#
# • Provide one paragraph of coaching advice for contest preparation.
#
# After generating all content, compile everything into a single downloadable PDF format (text ready to copy into a word processor).
#
# Output instructions:
#
# - Clean, minimal styling — simple grid, no heavy color blocks.
#
# - Questions run continuously with forced page breaks between sub-tables.
#
# - Questions and Answer key should have a page forced page break.
#
# - Answer key mirrors the same layout as the question tables.
#
# - Answer key runs continuously without forced page breaks between sub-tables.
#
# - Compile everything into a single downloadable PDF.
#
# """
#
#
#
# ```

# %% [markdown]
# ### Use the prompt, generated in previous setp, to get the file with questions and answers as a document (.docx) or as PDF file

# %%
"""

Use the Saved Pattern: MathLeague.org Practice Pack Generation for following

As a math teacher who writes MathLeague.org practice materials, create a
complete "Multiply by 125" practice pack.

Follow the PDF file structure provided.

Follow this exact structure:

Part A — 240 Practice Questions (Multiply by 125)

- Add a 1 or 2 line instruction like:
    Instructions: Multiply each number by 125. Use the shortcut method
    (divide by 8, then multiply by 1,000) where helpful.
    Write your answer in the space provided.

- Use only 2-digit, 3-digit, 4-digit, 5-digit, or decimal numbers.

- All questions must be of the form (number × 125) or (125 × number).

- Include a balanced mix of whole numbers and decimals:
    - Whole numbers: 2-digit, 3-digit, 4-digit, 5-digit
    - Decimals: one decimal place (e.g. 12.5 × 125) and
                two decimal places (e.g. 125 × 3.75)

- Format each question exactly like this:
    1. 128 × 125 =
    2. 125 × 1,284 =
    3. 12,438 × 125 =
    4. 12.5 × 125 =
    5. 125 × 3.5 =

- Do NOT repeat numbers.
- Do NOT create sequential patterns.
- Mix difficulty levels throughout.
- Provide space for answer between 2 columns.
- Split questions in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Use markdown grid tables.
  Each table has 15 rows (30 questions total).
  Example:

  | 1.  128 × 125 =      | 16. 125 × 34.5 =   |
  |----------------------|--------------------|
  | 2.  125 × 5,234 =    | 17. 729 × 125 =    |
  | 3.  12,438 × 125 =   | 18. 125 × 6,712 =  |
  | 4.  12.5 × 125 =     | 19. 3,891 × 125 =  |
  | 5.  125 × 3.5 =      | 20. 125 × 47.25 =  |
  (continue for all 30 questions)

- 8 tables total (Tables 1–8), 30 questions each = 240 total.
- Forced page break between each table.

Part B — Answer Key

- Add a 1 or 2 line instruction like:
    Instructions: Check your answers below. Answers are listed in order.
    Use the shortcut method to verify your work.

- Provide all 240 answers in order.

- Format each answer exactly like this:
    1. {Answer}

- Split answers in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Same two-column, 15-row, 30-answer layout as Part A.
  Example:

  | 1.  16,000       | 16. 4,312.5      |
  |------------------|------------------|
  | 2.  160,500      | 17. 91,125       |
  | 3.  1,554,750    | 18. 839,000      |
  | 4.  1,562.5      | 19. 486,375      |
  | 5.  437.5        | 20. 5,906.25     |
  (continue for all 30 answers)

- 8 tables total (Tables 1–8), 30 answers each = 240 total.
- Answer key runs continuously without forced page breaks
  between sub-tables.
- Forced page break between Part A and Part B.

Part C — Explanation Section

- Explain the Multiply-by-125 shortcut:
    - Core method: number × 125 = (number ÷ 8) × 1,000
    - Alternative: number × 125 = number × 1,000 ÷ 8
    - Why it works: 125 = 1,000 ÷ 8
    - Tip for divisibility: works cleanest when the number
      is divisible by 8; for others, divide carefully and
      keep the decimal.
    - Decimal method: apply the same shortcut, then place
      the decimal point correctly in the result.
- Show why the method works (125 = 10^3 ÷ 8 = 1,000 ÷ 8).
- Show how to handle numbers not divisible by 8 and
  decimal inputs using the same shortcut.
- Provide 5 fully worked examples:
    1. 128 × 125    (divisible by 8 — clean result)
    2. 1,284 × 125  (not divisible by 8 — decimal result)
    3. 12,438 × 125 (large number)
    4. 12.5 × 125   (decimal input)
    5. 125 × 3.5    (small decimal input)

Part D — Math League Teaching Strategy

- Provide speed tips, pattern recognition strategies, mental-math
  shortcuts, and common mistakes students make, including:
    - Forgetting to divide by 8 before multiplying by 1,000
    - Misplacing the decimal point with decimal inputs
    - Confusing × 125 shortcut with × 0.125 shortcut
    - Not recognizing when a number is evenly divisible by 8
    - Confusing the × 125 shortcut with the × 25 shortcut
      (÷ 4 × 100) and mixing up the divisor and multiplier
    - Losing track of zeros when multiplying by 1,000

Part E — Teacher Notes

- Provide one paragraph of coaching advice for contest preparation
  focused on Multiply-by-125 problems commonly seen in Math League
  competitions, including how to build speed and accuracy with
  both whole number and decimal inputs, how to quickly check
  divisibility by 8, and how to avoid decimal placement errors
  under time pressure.

Output instructions:
- After generating all content, compile everything into a single
  downloadable PDF format (text ready to copy into a word processor).
- Clean, minimal styling — simple grid, no heavy color blocks.
- Questions run continuously with forced page breaks between sub-tables.
- Questions and Answer Key should have a forced page break between them.
- Answer key mirrors the same layout as the question tables.
- Answer key runs continuously without forced page breaks between
  sub-tables.
- Compile everything into a single downloadable PDF.

"""

# %% [markdown]
# ## Multiply_by_11
#
#
#
# *   File: Multiply_by_11_Practice_Pack_

# %% [markdown]
# ### Generate the Prompt from given Question Sample

# %% [markdown]
# > Prompt
#
# >
# for the given question:
#
#
#
#
# ```
# """
#
#   1. 128 × 11 =
#
#   1. 1284 × 11 =
#
#   1. 12438 × 11 =
#
#   1. 12.5 * 11 =
#
#   1. 11 * 3.5 =
#
# """
#
#
# ```
#
# Generate a prompt in the Given format:
#
# ```
# """
#
# Use the Saved Pattern: MathLeague.org Practice Pack Generation for following
#
# As a math teacher who writes MathLeague.org practice materials, create a complete “Multiply by 25” practice pack.
#
# Follow the PDF file structure provided.
#
# Follow this exact structure:
#
# Part A — 240 Practice Questions (Multiply by 25)
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Multiply each number by 25. Use the shortcut method (divide by 4, then multiply by 100) where helpful.
#
#     Write your answer in the space provided.
#
# • Use only 2-digit, 3-digit, 4-digit, 5-digit, or decimal numbers.
#
# • All questions must be of the form (number × 25) or (25 × number).
#
# • Include a balanced mix of whole numbers and decimals.
#
# • Format each question exactly like this:
#
#     1. 128 × 25 =
#
#     2. 25 × 1,284 =
#
#     3. 11,438 × 25 =
#
# • Do NOT repeat numbers.
#
# • Do NOT create sequential patterns.
#
# • Mix difficulty levels.
#
# • Provide space for answer between 2 columns.
#
# • Split questions in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Use markdown grid tables. Each table has 15 rows (30 questions total).
#
#   Example:
#
#   | 1. 128 × 25 = | 16. 25 × 34.5 = |
#
#   |----------------|------------------|
#
#   | 2. 25 × 5,234 = | 17. 729 × 25 = |
#
#   (continue for all 30 questions)
#
# • 8 tables total (Tables 1–8).
#
# Part B — Answer Key
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Check your answers below. Answers are in order. Use the shortcut to check your work.
#
# • Provide all 240 answers in order.
#
# • Format each answer exactly like this:
#
#     1. {Answer}
#
# • Split answers in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Same two-column, 15-row, 30-answer table layout as Part A.
#
#   Example:
#
#   | 1. 3200 | 16. 862.5 |
#
#   |---------|----------|
#
#   | 2. 130850 | 17. 18225 |
#
# • 8 tables total (Tables 1–8).
#
# Part C — Explanation Section
#
# • Explain the Multiply-by-25 shortcut.
#
# • Show why the method works.
#
# • Provide 5 fully worked examples.
#
# Part D — Math League Teaching Strategy
#
# • Provide speed tips, pattern recognition strategies, mental-math shortcuts, and common mistakes students make.
#
# Part E — Teacher Notes
#
# • Provide one paragraph of coaching advice for contest preparation.
#
# After generating all content, compile everything into a single downloadable PDF format (text ready to copy into a word processor).
#
# Output instructions:
#
# - Clean, minimal styling — simple grid, no heavy color blocks.
#
# - Questions run continuously with forced page breaks between sub-tables.
#
# - Questions and Answer key should have a page forced page break.
#
# - Answer key mirrors the same layout as the question tables.
#
# - Answer key runs continuously without forced page breaks between sub-tables.
#
# - Compile everything into a single downloadable PDF.
#
# """
#
#
# ```

# %% [markdown]
# ### Use the prompt, generated in previous setp, to get the file with questions and answers as a document (.docx) or as PDF file

# %%
"""

Use the Saved Pattern: MathLeague.org Practice Pack Generation for following

As a math teacher who writes MathLeague.org practice materials, create a
complete "Multiply by 11" practice pack.

Follow the PDF file structure provided.

Follow this exact structure:

Part A — 240 Practice Questions (Multiply by 11)

- Add a 1 or 2 line instruction like:
    Instructions: Multiply each number by 11. Use the shortcut method
    (add adjacent digits and insert the sum between them) where helpful.
    Write your answer in the space provided.

- Use only 2-digit, 3-digit, 4-digit, 5-digit, or decimal numbers.

- All questions must be of the form (number × 11) or (11 × number).

- Include a balanced mix of whole numbers and decimals:
    - Whole numbers: 2-digit, 3-digit, 4-digit, 5-digit
    - Decimals: one decimal place (e.g. 12.5 × 11) and
                two decimal places (e.g. 11 × 3.75)

- Format each question exactly like this:
    1. 128 × 11 =
    2. 11 × 1,284 =
    3. 12,438 × 11 =
    4. 12.5 × 11 =
    5. 11 × 3.5 =

- Do NOT repeat numbers.
- Do NOT create sequential patterns.
- Mix difficulty levels throughout.
- Provide space for answer between 2 columns.
- Split questions in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Use markdown grid tables.
  Each table has 15 rows (30 questions total).
  Example:

  | 1.  128 × 11 =      | 16. 11 × 34.5 =   |
  |---------------------|-------------------|
  | 2.  11 × 5,234 =    | 17. 729 × 11 =    |
  | 3.  12,438 × 11 =   | 18. 11 × 6,712 =  |
  | 4.  12.5 × 11 =     | 19. 3,891 × 11 =  |
  | 5.  11 × 3.5 =      | 20. 11 × 47.25 =  |
  (continue for all 30 questions)

- 8 tables total (Tables 1–8), 30 questions each = 240 total.
- Forced page break between each table.

Part B — Answer Key

- Add a 1 or 2 line instruction like:
    Instructions: Check your answers below. Answers are listed in order.
    Use the shortcut method to verify your work.

- Provide all 240 answers in order.

- Format each answer exactly like this:
    1. {Answer}

- Split answers in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Same two-column, 15-row, 30-answer layout as Part A.
  Example:

  | 1.  1,408      | 16. 379.5     |
  |----------------|---------------|
  | 2.  57,574     | 17. 8,019     |
  | 3.  136,818    | 18. 73,832    |
  | 4.  137.5      | 19. 42,801    |
  | 5.  38.5       | 20. 519.75    |
  (continue for all 30 answers)

- 8 tables total (Tables 1–8), 30 answers each = 240 total.
- Answer key runs continuously without forced page breaks
  between sub-tables.
- Forced page break between Part A and Part B.

Part C — Explanation Section

- Explain the Multiply-by-11 shortcut:
    - Core method for 2-digit numbers:
        Write the first digit, add both digits for the middle,
        write the last digit.
        e.g. 11 × 36: first=3, middle=3+6=9, last=6 → 396
    - Extended method for 3+ digit numbers:
        Work from right to left, adding adjacent pairs,
        carrying when the sum exceeds 9.
        e.g. 11 × 128: 8, (2+8)=10 write 0 carry 1,
                       (1+2)+1=4, 1 → 1,408
    - Decimal method: apply the same shortcut, then place
        the decimal point correctly in the result.
- Show why the method works
    (11 = 10 + 1, so n × 11 = n × 10 + n × 1).
- Show how to handle carrying and decimals using the same shortcut.
- Provide 5 fully worked examples:
    1. 128 × 11
    2. 1,284 × 11
    3. 12,438 × 11
    4. 12.5 × 11
    5. 11 × 3.5

Part D — Math League Teaching Strategy

- Provide speed tips, pattern recognition strategies, mental-math
  shortcuts, and common mistakes students make, including:
    - Forgetting to carry when adjacent digits sum to 10 or more
    - Misplacing the decimal point with decimal inputs
    - Only knowing the 2-digit trick and not the extended method
    - Losing track of position when working with 5-digit numbers
    - Confusing the direction (left-to-right vs right-to-left)
      when applying the shortcut

Part E — Teacher Notes

- Provide one paragraph of coaching advice for contest preparation
  focused on Multiply-by-11 problems commonly seen in Math League
  competitions, including how to build speed and accuracy with
  both whole number and decimal inputs, and how to avoid
  carry errors under time pressure.

Output instructions:
- After generating all content, compile everything into a single
  downloadable PDF format (text ready to copy into a word processor).
- Clean, minimal styling — simple grid, no heavy color blocks.
- Questions run continuously with forced page breaks between sub-tables.
- Questions and Answer Key should have a forced page break between them.
- Answer key mirrors the same layout as the question tables.
- Answer key runs continuously without forced page breaks between
  sub-tables.
- Compile everything into a single downloadable PDF.

"""

# %% [markdown]
# ## Multiply_by_25
#
#
#
# *   File: Multiply_by_25_Practice_Pack_.

# %% [markdown]
# ### Generate the Prompt from given Question Sample

# %% [markdown]
# > Prompt
#
# >
#
# for the given question:
#
# ```
# """
#
#   1. 128 × 25 =
#
#   1. 1284 × 25 =
#
#   1. 12438 × 25 =
#
#   1. 12.5 * 25 =
#
#   1. 25 * 3.5 =
#
# """
#
# ```
#
# Generate a prompt in the Given format:
#
# ```
# """
#
# Use the Saved Pattern: MathLeague.org Practice Pack Generation for following
#
# As a math teacher who writes MathLeague.org practice materials, create a complete “Multiply by 25” practice pack.
#
# Follow the PDF file structure provided.
#
# Follow this exact structure:
#
# Part A — 240 Practice Questions (Multiply by 25)
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Multiply each number by 25. Use the shortcut method (divide by 4, then multiply by 100) where helpful.
#
#     Write your answer in the space provided.
#
# • Use only 2-digit, 3-digit, 4-digit, 5-digit, or decimal numbers.
#
# • All questions must be of the form (number × 25) or (25 × number).
#
# • Include a balanced mix of whole numbers and decimals.
#
# • Format each question exactly like this:
#
#     1. 128 × 25 =
#
#     2. 25 × 1,284 =
#
#     3. 11,438 × 25 =
#
# • Do NOT repeat numbers.
#
# • Do NOT create sequential patterns.
#
# • Mix difficulty levels.
#
# • Provide space for answer between 2 columns.
#
# • Split questions in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Use markdown grid tables. Each table has 15 rows (30 questions total).
#
#   Example:
#
#   | 1. 128 × 25 = | 16. 25 × 34.5 = |
#
#   |----------------|------------------|
#
#   | 2. 25 × 5,234 = | 17. 729 × 25 = |
#
#   (continue for all 30 questions)
#
# • 8 tables total (Tables 1–8).
#
# Part B — Answer Key
#
# • Add a 1 or 2 line instructions like:
#
#     Instructions: Check your answers below. Answers are in order. Use the shortcut to check your work.
#
# • Provide all 240 answers in order.
#
# • Format each answer exactly like this:
#
#     1. {Answer}
#
# • Split answers in 2 columns like (1 with 16, 2 with 17, etc.)
#
# • TABLE STRUCTURE: Same two-column, 15-row, 30-answer table layout as Part A.
#
#   Example:
#
#   | 1. 3200 | 16. 862.5 |
#
#   |---------|----------|
#
#   | 2. 130850 | 17. 18225 |
#
# • 8 tables total (Tables 1–8).
#
# Part C — Explanation Section
#
# • Explain the Multiply-by-25 shortcut.
#
# • Show why the method works.
#
# • Provide 5 fully worked examples.
#
# Part D — Math League Teaching Strategy
#
# • Provide speed tips, pattern recognition strategies, mental-math shortcuts, and common mistakes students make.
#
# Part E — Teacher Notes
#
# • Provide one paragraph of coaching advice for contest preparation.
#
# After generating all content, compile everything into a single downloadable PDF format (text ready to copy into a word processor).
#
# Output instructions:
#
# - Clean, minimal styling — simple grid, no heavy color blocks.
#
# - Questions run continuously with forced page breaks between sub-tables.
#
# - Questions and Answer key should have a page forced page break.
#
# - Answer key mirrors the same layout as the question tables.
#
# - Answer key runs continuously without forced page breaks between sub-tables.
#
# - Compile everything into a single downloadable PDF.
#
# """
#
# ```

# %% [markdown]
# ### Use the prompt, generated in previous setp, to get the file with questions and answers as a document (.docx) or as PDF file

# %%
"""

Use the Saved Pattern: MathLeague.org Practice Pack Generation for following

As a math teacher who writes MathLeague.org practice materials, create a
complete "Multiply by 25" practice pack.

Follow the PDF file structure provided.

Follow this exact structure:

Part A — 240 Practice Questions (Multiply by 25)

- Add a 1 or 2 line instruction like:
    Instructions: Multiply each number by 25. Use the shortcut method
    (divide by 4, then multiply by 100) where helpful.
    Write your answer in the space provided.

- Use only 2-digit, 3-digit, 4-digit, 5-digit, or decimal numbers.

- All questions must be of the form (number × 25) or (25 × number).

- Include a balanced mix of whole numbers and decimals:
    - Whole numbers: 2-digit, 3-digit, 4-digit, 5-digit
    - Decimals: one decimal place (e.g. 12.5 × 25) and
                two decimal places (e.g. 25 × 3.75)

- Format each question exactly like this:
    1. 128 × 25 =
    2. 25 × 1,284 =
    3. 11,438 × 25 =
    4. 12.5 × 25 =
    5. 25 × 3.5 =

- Do NOT repeat numbers.
- Do NOT create sequential patterns.
- Mix difficulty levels throughout.
- Provide space for answer between 2 columns.
- Split questions in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Use markdown grid tables.
  Each table has 15 rows (30 questions total).
  Example:

  | 1.  128 × 25 =      | 16. 25 × 34.5 =   |
  |---------------------|-------------------|
  | 2.  25 × 5,234 =    | 17. 729 × 25 =    |
  | 3.  11,438 × 25 =   | 18. 25 × 6,712 =  |
  | 4.  12.5 × 25 =     | 19. 3,891 × 25 =  |
  | 5.  25 × 3.5 =      | 20. 25 × 47.25 =  |
  (continue for all 30 questions)

- 8 tables total (Tables 1–8), 30 questions each = 240 total.
- Forced page break between each table.

Part B — Answer Key

- Add a 1 or 2 line instruction like:
    Instructions: Check your answers below. Answers are listed in order.
    Use the shortcut method to verify your work.

- Provide all 240 answers in order.

- Format each answer exactly like this:
    1. {Answer}

- Split answers in 2 columns like (1 with 16, 2 with 17, etc.)

- TABLE STRUCTURE: Same two-column, 15-row, 30-answer layout as Part A.
  Example:

  | 1.  3,200      | 16. 862.5     |
  |----------------|---------------|
  | 2.  130,850    | 17. 18,225    |
  | 3.  285,950    | 18. 167,800   |
  | 4.  312.5      | 19. 97,275    |
  | 5.  87.5       | 20. 1,181.25  |
  (continue for all 30 answers)

- 8 tables total (Tables 1–8), 30 answers each = 240 total.
- Answer key runs continuously without forced page breaks
  between sub-tables.
- Forced page break between Part A and Part B.

Part C — Explanation Section

- Explain the Multiply-by-25 shortcut:
    - Core method: number × 25 = (number ÷ 4) × 100
    - Alternative: number × 25 = number × 100 ÷ 4
- Show why the method works (25 = 100 ÷ 4).
- Show how to handle decimals using the same shortcut.
- Provide 5 fully worked examples:
    1. 128 × 25
    2. 1,284 × 25
    3. 12,438 × 25
    4. 12.5 × 25
    5. 25 × 3.5

Part D — Math League Teaching Strategy

- Provide speed tips, pattern recognition strategies, mental-math
  shortcuts, and common mistakes students make, including:
    - Forgetting to divide before multiplying by 100
    - Misplacing the decimal point with decimal inputs
    - Confusing × 25 shortcut with × 0.25 shortcut
    - Not recognizing when a number is evenly divisible by 4

Part E — Teacher Notes

- Provide one paragraph of coaching advice for contest preparation
  focused on Multiply-by-25 problems commonly seen in Math League
  competitions, including how to build speed and accuracy with
  both whole number and decimal inputs.

Output instructions:
- After generating all content, compile everything into a single
  downloadable PDF format (text ready to copy into a word processor).
- Clean, minimal styling — simple grid, no heavy color blocks.
- Questions run continuously with forced page breaks between sub-tables.
- Questions and Answer Key should have a forced page break between them.
- Answer key mirrors the same layout as the question tables.
- Answer key runs continuously without forced page breaks between
  sub-tables.
- Compile everything into a single downloadable PDF.

"""
